# %%
# Game Bounce(간단한 게임 만들기)
# 패들과 공이 존재
# 공이 움직임
# 공이 떨어지지 않도록 패들을 움직임

# %%
# import module
from tkinter import *
import random
import time

# create class ball
class Ball:
    def __init__(self, canvas, paddle, color):
        self.canvas = canvas
        self.paddle = paddle
        self.id = canvas.create_oval(10, 10, 45, 45, fill = color) # ball size
        self.canvas.move(self.id, 245, 100)
        starts = [-3, -2, -1, 1, 2, 3]
        random.shuffle(starts)
        self.x = starts[0]
        self.y = -3
        self.canvas_height = self.canvas.winfo_height()
        self.canvas_width = self.canvas.winfo_width()
        
        self.hit_bottom = False
    def hit_paddle(self, pos):
        paddle_pos = self.canvas.coords(self.paddle.id)
        if pos[2] >= paddle_pos[0] and pos[0] <= paddle_pos[2]:
            if pos[3] >= paddle_pos[1] and pos[3] <= paddle_pos[3]:
                return True
        return False
    
    def draw(self):
        self.canvas.move(self.id, self.x, self.y)
        pos = self.canvas.coords(self.id)
        if pos[1] <= 0:
            self.y = 3
        if pos[3] >= self.canvas_height:
            self.hit_bottom = True
        if self.hit_paddle(pos) == True:
            self.y = -3
        if pos[0] <= 0:
            self.x = 3
        if pos[2] >= self.canvas_width:
            self.x = -3

# create class paddle
class Paddle:
    def __init__(self, canvas, color):
        self.canvas = canvas
        self.id = canvas.create_rectangle(0, 0, 230, 25, fill = color) # paddle size
        self.canvas.move(self.id, 200, 300)
        self.x = 0
        self.canvas_width = self.canvas.winfo_width()
        self.canvas.bind_all('<KeyPress-Left>', self.turn_left)
        self.canvas.bind_all('<KeyPress-Right>', self.turn_right)
        
    def turn_left(self, evt):
        self.x = -3
        
    def turn_right(self, evt):
        self.x = 3
        
    def draw(self):
        self.canvas.move(self.id, self.x, 0)
        pos = self.canvas.coords(self.id)
        if pos[0] <= 0:
            self.x = 0
        elif pos[2] >= self.canvas_width:
            self.x = 0
        
# main process
tk = Tk()
tk.title("Game")
tk.resizable(0, 0)
tk.wm_attributes("-topmost", 1)
canvas = Canvas(tk, width = 500, height = 400, bd = 0, highlightthickness = 0)
canvas.pack()
tk.update()
paddle = Paddle(canvas, 'blue') # show paddle
ball = Ball(canvas, paddle, 'pink') # show ball
while 1:
    if ball.hit_bottom == False:
        ball.draw()
        paddle.draw()
    tk.update_idletasks()
    tk.update()
    time.sleep(0.07)
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Input In [3], in <cell line: 78>()
#      77 while 1:
#      78     if ball.hit_bottom == False:
# ---> 79         ball.draw()
#      80         paddle.draw()
#      81     tk.update_idletasks()
#
# Input In [3], in Ball.draw(self)
#      28 def draw(self):
# ---> 29     self.canvas.move(self.id, self.x, self.y)
#      30     pos = self.canvas.coords(self.id)
#      31     if pos[1] <= 0:
#
# File ~/opt/anaconda3/lib/python3.9/tkinter/__init__.py:2920, in Canvas.move(self, *args)
#    2918 def move(self, *args):
#    2919     """Move an item TAGORID given in ARGS."""
# -> 2920     self.tk.call((self._w, 'move') + args)
#
# TclError: invalid command name ".!canvas"
