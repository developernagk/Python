# %%
tuple_test = (10, 20 , 30)
tuple_test[0]
# Out:
# 10

# %%
tuple_test[1]
# Out:
# 20

# %%
tuple_test[2]
# Out:
# 30

# %%
# tuple_basic
# 리스트와 튜플의 특이한 사용
[a, b] = [10, 20]
(c, d) = (10, 20)

# 출력합니다
print("a : ", a)
print("b : ", b)
print("c : ", c)
print("d : ", d)
# Out:
# a :  10
# b :  20
# c :  10
# d :  20

# %%
# tuple_use01
# 괄호가 없는 튜플
tuple_test = 10, 20, 30, 40
print("# 괄호가 없는 튜플의 값과 자료형 출력")
print("tuple_test : ", tuple_test)
print("type(tuple_test)", type(tuple_test))
print()

# 괄호가 없는 튜플 활용
a, b, c = 10, 20, 30
print("# 괄호가 없는 튜플을 활용한 할당")
print("a : ", a)
print("b : ", b)
print("c : ", c)
# Out:
# # 괄호가 없는 튜플의 값과 자료형 출력
# tuple_test :  (10, 20, 30, 40)
# type(tuple_test) <class 'tuple'>
#
# # 괄호가 없는 튜플을 활용한 할당
# a :  10
# b :  20
# c :  30

# %%
# tuple_use02
a, b = 10, 20

print("# 교환 전 값")
print("a : ", a)
print("b : ", b)
print()

# 값을 교환합니다
a, b = b, a

print("# 교환 후 값")
print("a : ", a)
print("b : ", b)
print()
# Out:
# # 교환 전 값
# a :  10
# b :  20
#
# # 교환 후 값
# a :  20
# b :  10

# %%
# tuple_return
# 함수를 선언합니다
def test():
    return(10, 20)

# 여러 개의 값을 리턴받습니다
a, b = test()

# 출력합니다
print("a : ", a)
print("b ; ", b)
# Out:
# a :  10
# b ;  20

# %%
# func_as_param
# 매개변수로 받은 함수를 10번 호출하는 함수
def call_10_times(func):
    for i in range(10):
        func()
        
# 간단한 출력하는 함수
def print_hello():
    print("안녕하세요")
    
# 조합하기
call_10_times(print_hello)
# Out:
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요

# %%
# call_with_func
# 함수를 선언합니다
def power(item):
    return item * item
def under_3(item):
    return item < 3

# 변수를 선언합니다
list_input_a = [1, 2, 3, 4, 5]

# map() 함수를 사용합니다
output_a = map(power, list_input_a)
print("# map() 함수의 실행 결과")
print("map(power, list_input_a) : ", output_a)
print("map(power, list_input_a) : ", list(output_a))
print()

# filter() 함수를 사용합니다
output_b = filter(under_3, list_input_a)
print("# filter() 함수의 실행 결과")
print("filter(under_3, list_input_a) : ", output_b)
print("filter(under_3, list_input_a) : ", list(output_b))
# Out:
# # map() 함수의 실행 결과
# map(power, list_input_a) :  <map object at 0x7fa6c8010160>
# map(power, list_input_a) :  [1, 4, 9, 16, 25]
#
# # filter() 함수의 실행 결과
# filter(under_3, list_input_a) :  <filter object at 0x7fa6c80387f0>
# filter(under_3, list_input_a) :  [1, 2]

# %%
# lambda01
# 함수를 선언합니다
power = lambda x : x * x
under_3 = lambda x : x < 3

# 변수를 선언합니다
list_input_a = [1, 2, 3, 4, 5]

# map() 함수를 사용합니다
output_a = map(power, list_input_a)
print("# map() 함수의 실행 결과")
print("map(power, list_input_a) : ", output_a)
print("map(power, list_input_a) : ", list(output_a))
print()

# filter() 함수를 사용합니다
output_b = filter(under_3, list_input_a)
print("# filter() 함수의 실행 결과")
print("filter(under_3, list_input_a) : ", output_b)
print("filter(under_3, list_input_a) : ", list(output_b))
# Out:
# # map() 함수의 실행 결과
# map(power, list_input_a) :  <map object at 0x7fa6f88d6fa0>
# map(power, list_input_a) :  [1, 4, 9, 16, 25]
#
# # filter() 함수의 실행 결과
# filter(under_3, list_input_a) :  <filter object at 0x7fa6c8038cd0>
# filter(under_3, list_input_a) :  [1, 2]

# %%
# lambda02
# 변수를 선언합니다
list_input_a = [1, 2, 3, 4, 5]

# map() 함수를 사용합니다
output_a = map(lambda x : x * x, list_input_a)
print("# map() 함수의 실행 결과")
print("map(power, list_input_a) : ", output_a)
print("map(power, list_input_a) : ", list(output_a))
print()

# filter() 함수를 사용합니다
output_b = filter(lambda x : x < 3, list_input_a)
print("# filter() 함수의 실행 결과")
print("filter(under_3, list_input_a) : ", output_b)
print("filter(under_3, list_input_a) : ", list(output_b))
# Out:
# # map() 함수의 실행 결과
# map(power, list_input_a) :  <map object at 0x7fa6c8010310>
# map(power, list_input_a) :  [1, 4, 9, 16, 25]
#
# # filter() 함수의 실행 결과
# filter(under_3, list_input_a) :  <filter object at 0x7fa6c8038550>
# filter(under_3, list_input_a) :  [1, 2]

# %%
# file_open
# 파일을 엽니다
file = open("basic.txt", "w")

# 파일에 텍스트를 씁니다
file.write("Hello Python Programming...!")

# 파일을 닫습니다
file.close()

# %%
# 파일을 엽니다
with open("basic.txt", "w") as file:
    # 파일 위에 텍스트를 씁니다
    file.write("Hello Python Programming...!")

# %%
# file_read
# 파일을 엽니다
with open("basic.txt", "r") as file:
    # 파일을 읽고 출력합니다
    contents = file.read()
print(contents)
# Out:
# Hello Python Programming...!

# %%
# file_write
# 랜덤한 숫자를 만들기 위해 가져옵니다
import random
# 간단한 한글 리스트를 만듭니다
hanguls = list("가나다라마바사아자차카파타하")
# 파일을 쓰기 모드로 엽니다
with open("info.txt", "w") as file:
    for i in range(1000):
        # 랜덤한 값으로 변수를 생성합니다
        name = random.choice(hanguls) + random.choice(hanguls)
        weight = random.randrange(40, 100)
        height = random.randrange(140, 200)
        # 텍스트를 씁니다
        file.write("{}, {}, {}\n".format(name, weight, height))

# %%
# file.readlines
with open("info.txt", "r") as file:
    for line in file:
        # 변수를 선언합니다
        (name, weight, height) = line.strip().split(", ")
        
        # 데이터가 문제없는지 확인합니다: 문제가 있으면 지나감
        if (not name) or (not weight) or (not height):
            continue
        # 결과를 계산합니다
        bmi = int(weight) / ((int(height) / 100) ** 2)
        result = ""
        if 25 <= bmi:
            result = "과체중"
        elif 18.5 <= bmi:
            result = "정상 체중"
        else:
            result = "저체중"
            
        # 출력합니다
        print('\n'.join([
            "이름 : {}", 
            "몸무게 : {}", 
            "키 : {}", 
            "BMI : {}", 
            "결과 : {}"
        ]).format(name, weight, height, bmi, result))
        print()
# Out:
# 이름 : 나아
# 몸무게 : 44
# 키 : 192
# BMI : 11.93576388888889
# 결과 : 저체중
#
# 이름 : 카차
# 몸무게 : 85
# 키 : 192
# BMI : 23.057725694444446
# 결과 : 정상 체중
#
# 이름 : 카나
# 몸무게 : 74
# 키 : 145
# BMI : 35.196195005945306
# 결과 : 과체중
#
# 이름 : 가타
# 몸무게 : 83
# 키 : 183
# BMI : 24.78425751739377
# 결과 : 정상 체중
#
# 이름 : 파바
# 몸무게 : 90
# 키 : 174
# BMI : 29.72651605231867
# 결과 : 과체중
#
# 이름 : 차하
# 몸무게 : 80
# 키 : 181
# BMI : 24.41927902078691
# 결과 : 정상 체중
#
# 이름 : 바바
# 몸무게 : 57
# 키 : 154
# BMI : 24.034407151290267
# 결과 : 정상 체중
#
# 이름 : 다파
# 몸무게 : 58
# 키 : 197
# BMI : 14.944986987554433
# 결과 : 저체중
#
# 이름 : 사다
# 몸무게 : 64
# 키 : 184
# BMI : 18.90359168241966
# 결과 : 정상 체중
#
# 이름 : 다차
# 몸무게 : 98
# 키 : 178
# BMI : 30.930438076000502
# 결과 : 과체중
#
# 이름 : 나가
# 몸무게 : 42
# 키 : 145
# BMI : 19.976218787158146
# 결과 : 정상 체중
#
# 이름 : 하바
# 몸무게 : 71
# 키 : 176
# BMI : 22.920971074380166
# 결과 : 정상 체중
#
# 이름 : 가카
# 몸무게 : 48
# 키 : 169
# BMI : 16.806134238997235
# 결과 : 저체중
#
# 이름 : 하아
# 몸무게 : 50
# 키 : 157
# BMI : 20.28479857195018
# 결과 : 정상 체중
#
# 이름 : 마아
# 몸무게 : 51
# 키 : 166
# BMI : 18.507766003774133
# 결과 : 정상 체중
#
# 이름 : 하아
# 몸무게 : 85
# 키 : 187
# BMI : 24.307243558580453
# 결과 : 정상 체중
#
# 이름 : 나타
# 몸무게 : 74
# 키 : 173
# BMI : 24.725182932941294
# 결과 : 정상 체중
#
# 이름 : 아나
# 몸무게 : 47
# 키 : 147
# BMI : 21.75019667731038
# 결과 : 정상 체중
#
# 이름 : 하다
# 몸무게 : 74
# 키 : 162
# BMI : 28.19692120103642
# 결과 : 과체중
#
# 이름 : 자마
# 몸무게 : 53
# 키 : 193
# BMI : 14.228569894493813
# 결과 : 저체중
#
# 이름 : 하다
# 몸무게 : 67
# 키 : 141
# BMI : 33.70051808259142
# 결과 : 과체중
#
# 이름 : 나파
# 몸무게 : 48
# 키 : 174
# BMI : 15.854141894569956
# 결과 : 저체중
#
# 이름 : 파하
# 몸무게 : 85
# 키 : 146
# BMI : 39.876149371364235
# 결과 : 과체중
#
# 이름 : 바나
# 몸무게 : 55
# 키 : 152
# BMI : 23.80540166204986
# 결과 : 정상 체중
#
# 이름 : 나바
# 몸무게 : 87
# 키 : 153
# BMI : 37.165192874535435
# 결과 : 과체중
#
# 이름 : 나타
# 몸무게 : 49
# 키 : 191
# BMI : 13.431649351717333
# 결과 : 저체중
#
# 이름 : 다나
# 몸무게 : 97
# 키 : 191
# BMI : 26.589183410542475
# 결과 : 과체중
#
# 이름 : 차바
# 몸무게 : 58
# 키 : 153
# BMI : 24.77679524969029
# 결과 : 정상 체중
#
# 이름 : 카가
# 몸무게 : 51
# 키 : 185
# BMI : 14.901387874360847
# 결과 : 저체중
#
# 이름 : 타하
# 몸무게 : 55
# 키 : 180
# BMI : 16.975308641975307
# 결과 : 저체중
#
# 이름 : 타자
# 몸무게 : 77
# 키 : 190
# BMI : 21.329639889196677
# 결과 : 정상 체중
#
# 이름 : 바다
# 몸무게 : 97
# 키 : 181
# BMI : 29.60837581270413
# 결과 : 과체중
#
# 이름 : 나라
# 몸무게 : 45
# 키 : 188
# BMI : 12.73200543232232
# 결과 : 저체중
#
# 이름 : 자사
# 몸무게 : 96
# 키 : 156
# BMI : 39.44773175542406
# 결과 : 과체중
#
# 이름 : 바라
# 몸무게 : 58
# 키 : 151
# BMI : 25.437480812245077
# 결과 : 과체중
#
# 이름 : 다아
# 몸무게 : 64
# 키 : 189
# BMI : 17.91663167324543
# 결과 : 저체중
#
# 이름 : 다카
# 몸무게 : 45
# 키 : 183
# BMI : 13.437248051599031
# 결과 : 저체중
#
# 이름 : 하마
# 몸무게 : 60
# 키 : 149
# BMI : 27.025809648214047
# 결과 : 과체중
#
# 이름 : 아바
# 몸무게 : 61
# 키 : 176
# BMI : 19.692665289256198
# 결과 : 정상 체중
#
# 이름 : 나사
# 몸무게 : 66
# 키 : 179
# BMI : 20.598608033457133
# 결과 : 정상 체중
#
# 이름 : 하사
# 몸무게 : 44
# 키 : 140
# BMI : 22.44897959183674
# 결과 : 정상 체중
#
# 이름 : 파사
# 몸무게 : 72
# 키 : 198
# BMI : 18.36547291092746
# 결과 : 저체중
#
# 이름 : 아나
# 몸무게 : 71
# 키 : 191
# BMI : 19.462185795345523
# 결과 : 정상 체중
#
# 이름 : 다바
# 몸무게 : 62
# 키 : 142
# BMI : 30.7478674866098
# 결과 : 과체중
#
# 이름 : 다타
# 몸무게 : 85
# 키 : 159
# BMI : 33.62208773387128
# 결과 : 과체중
#
# 이름 : 가바
# 몸무게 : 72
# 키 : 167
# BMI : 25.816630212628635
# 결과 : 과체중
#
# 이름 : 마바
# 몸무게 : 92
# 키 : 174
# BMI : 30.38710529792575
# 결과 : 과체중
#
# 이름 : 아카
# 몸무게 : 82
# 키 : 188
# BMI : 23.20054323223178
# 결과 : 정상 체중
#
# 이름 : 자사
# 몸무게 : 53
# 키 : 188
# BMI : 14.995473064735176
# 결과 : 저체중
#
# 이름 : 나라
# 몸무게 : 99
# 키 : 194
# BMI : 26.304601976830696
# 결과 : 과체중
#
# 이름 : 차바
# 몸무게 : 55
# 키 : 154
# BMI : 23.19109461966605
# 결과 : 정상 체중
#
# 이름 : 나나
# 몸무게 : 45
# 키 : 171
# BMI : 15.389350569405973
# 결과 : 저체중
#
# 이름 : 마차
# 몸무게 : 97
# 키 : 177
# BMI : 30.961728749720702
# 결과 : 과체중
#
# 이름 : 파바
# 몸무게 : 76
# 키 : 152
# BMI : 32.89473684210526
# 결과 : 과체중
#
# 이름 : 차자
# 몸무게 : 62
# 키 : 157
# BMI : 25.153150229218223
# 결과 : 과체중
#
# 이름 : 나바
# 몸무게 : 94
# 키 : 159
# BMI : 37.18207349392824
# 결과 : 과체중
#
# 이름 : 가차
# 몸무게 : 84
# 키 : 174
# BMI : 27.74474831549742
# 결과 : 과체중
#
# 이름 : 타차
# 몸무게 : 77
# 키 : 144
# BMI : 37.13348765432099
# 결과 : 과체중
#
# 이름 : 하카
# 몸무게 : 75
# 키 : 164
# BMI : 27.885187388459254
# 결과 : 과체중
#
# 이름 : 하가
# 몸무게 : 76
# 키 : 144
# BMI : 36.651234567901234
# 결과 : 과체중
#
# 이름 : 다라
# 몸무게 : 56
# 키 : 175
# BMI : 18.285714285714285
# 결과 : 저체중
#
# 이름 : 나바
# 몸무게 : 54
# 키 : 166
# BMI : 19.5964581216432
# 결과 : 정상 체중
#
# 이름 : 다카
# 몸무게 : 56
# 키 : 145
# BMI : 26.634958382877528
# 결과 : 과체중
#
# 이름 : 가카
# 몸무게 : 67
# 키 : 182
# BMI : 20.227025721531216
# 결과 : 정상 체중
#
# 이름 : 다바
# 몸무게 : 68
# 키 : 146
# BMI : 31.90091949709139
# 결과 : 과체중
#
# 이름 : 타사
# 몸무게 : 60
# 키 : 177
# BMI : 19.15158479364167
# 결과 : 정상 체중
#
# 이름 : 바파
# 몸무게 : 48
# 키 : 178
# BMI : 15.149602322939023
# 결과 : 저체중
#
# 이름 : 라카
# 몸무게 : 66
# 키 : 146
# BMI : 30.962657158941646
# 결과 : 과체중
#
# 이름 : 다타
# 몸무게 : 85
# 키 : 141
# BMI : 42.75438861224285
# 결과 : 과체중
#
# 이름 : 바다
# 몸무게 : 63
# 키 : 164
# BMI : 23.423557406305775
# 결과 : 정상 체중
#
# 이름 : 카다
# 몸무게 : 88
# 키 : 196
# BMI : 22.907122032486466
# 결과 : 정상 체중
#
# 이름 : 가파
# 몸무게 : 47
# 키 : 173
# BMI : 15.703832403354605
# 결과 : 저체중
#
# 이름 : 카가
# 몸무게 : 73
# 키 : 181
# BMI : 22.282592106468055
# 결과 : 정상 체중
#
# 이름 : 마차
# 몸무게 : 43
# 키 : 192
# BMI : 11.664496527777779
# 결과 : 저체중
#
# 이름 : 마마
# 몸무게 : 69
# 키 : 141
# BMI : 34.70650369699714
# 결과 : 과체중
#
# 이름 : 카카
# 몸무게 : 47
# 키 : 159
# BMI : 18.59103674696412
# 결과 : 정상 체중
#
# 이름 : 다차
# 몸무게 : 94
# 키 : 155
# BMI : 39.12591050988553
# 결과 : 과체중
#
# 이름 : 파카
# 몸무게 : 55
# 키 : 173
# BMI : 18.376825152861773
# 결과 : 저체중
#
# 이름 : 차다
# 몸무게 : 48
# 키 : 170
# BMI : 16.60899653979239
# 결과 : 저체중
#
# 이름 : 하파
# 몸무게 : 51
# 키 : 198
# BMI : 13.008876645240282
# 결과 : 저체중
#
# 이름 : 아차
# 몸무게 : 60
# 키 : 156
# BMI : 24.654832347140037
# 결과 : 정상 체중
#
# 이름 : 타사
# 몸무게 : 81
# 키 : 157
# BMI : 32.86137368655929
# 결과 : 과체중
#
# 이름 : 가나
# 몸무게 : 43
# 키 : 142
# BMI : 21.32513390200357
# 결과 : 정상 체중
#
# 이름 : 다아
# 몸무게 : 81
# 키 : 149
# BMI : 36.48484302508896
# 결과 : 과체중
#
# 이름 : 하바
# 몸무게 : 46
# 키 : 150
# BMI : 20.444444444444443
# 결과 : 정상 체중
#
# 이름 : 라카
# 몸무게 : 45
# 키 : 165
# BMI : 16.528925619834713
# 결과 : 저체중
#
# 이름 : 차하
# 몸무게 : 76
# 키 : 161
# BMI : 29.319856487018246
# 결과 : 과체중
#
# 이름 : 아라
# 몸무게 : 44
# 키 : 167
# BMI : 15.776829574384166
# 결과 : 저체중
#
# 이름 : 자다
# 몸무게 : 84
# 키 : 177
# BMI : 26.812218711098343
# 결과 : 과체중
#
# 이름 : 타카
# 몸무게 : 69
# 키 : 149
# BMI : 31.07968109544615
# 결과 : 과체중
#
# 이름 : 차차
# 몸무게 : 86
# 키 : 198
# BMI : 21.93653708805224
# 결과 : 정상 체중
#
# 이름 : 라카
# 몸무게 : 73
# 키 : 149
# BMI : 32.88140173866042
# 결과 : 과체중
#
# 이름 : 자자
# 몸무게 : 91
# 키 : 166
# BMI : 33.02366090869502
# 결과 : 과체중
#
# 이름 : 카나
# 몸무게 : 53
# 키 : 162
# BMI : 20.195092211553114
# 결과 : 정상 체중
#
# 이름 : 다카
# 몸무게 : 77
# 키 : 154
# BMI : 32.46753246753247
# 결과 : 과체중
#
# 이름 : 타바
# 몸무게 : 82
# 키 : 188
# BMI : 23.20054323223178
# 결과 : 정상 체중
#
# 이름 : 마하
# 몸무게 : 75
# 키 : 177
# BMI : 23.93948099205209
# 결과 : 정상 체중
#
# 이름 : 다타
# 몸무게 : 73
# 키 : 176
# BMI : 23.56663223140496
# 결과 : 정상 체중
#
# 이름 : 마카
# 몸무게 : 94
# 키 : 185
# BMI : 27.465303140978815
# 결과 : 과체중
#
# 이름 : 자차
# 몸무게 : 60
# 키 : 165
# BMI : 22.03856749311295
# 결과 : 정상 체중
#
# 이름 : 마라
# 몸무게 : 67
# 키 : 195
# BMI : 17.61998685075608
# 결과 : 저체중
#
# 이름 : 타나
# 몸무게 : 96
# 키 : 144
# BMI : 46.2962962962963
# 결과 : 과체중
#
# 이름 : 아차
# 몸무게 : 91
# 키 : 164
# BMI : 33.834027364663896
# 결과 : 과체중
#
# 이름 : 나라
# 몸무게 : 62
# 키 : 161
# BMI : 23.9188302920412
# 결과 : 정상 체중
#
# 이름 : 다차
# 몸무게 : 84
# 키 : 158
# BMI : 33.64845377343374
# 결과 : 과체중
#
# 이름 : 다자
# 몸무게 : 44
# 키 : 141
# BMI : 22.131683516925712
# 결과 : 정상 체중
#
# 이름 : 타바
# 몸무게 : 44
# 키 : 188
# BMI : 12.449071978270712
# 결과 : 저체중
#
# 이름 : 가자
# 몸무게 : 53
# 키 : 165
# BMI : 19.467401285583104
# 결과 : 정상 체중
#
# 이름 : 나라
# 몸무게 : 65
# 키 : 183
# BMI : 19.409358296754156
# 결과 : 정상 체중
#
# 이름 : 차나
# 몸무게 : 73
# 키 : 141
# BMI : 36.718474925808565
# 결과 : 과체중
#
# 이름 : 아자
# 몸무게 : 62
# 키 : 188
# BMI : 17.54187415119964
# 결과 : 저체중
#
# 이름 : 나다
# 몸무게 : 76
# 키 : 199
# BMI : 19.191434559733338
# 결과 : 정상 체중
#
# 이름 : 파차
# 몸무게 : 56
# 키 : 185
# BMI : 16.362308254200144
# 결과 : 저체중
#
# 이름 : 차다
# 몸무게 : 57
# 키 : 190
# BMI : 15.789473684210527
# 결과 : 저체중
#
# 이름 : 라마
# 몸무게 : 70
# 키 : 175
# BMI : 22.857142857142858
# 결과 : 정상 체중
#
# 이름 : 라차
# 몸무게 : 41
# 키 : 147
# BMI : 18.97357582488778
# 결과 : 정상 체중
#
# 이름 : 나가
# 몸무게 : 80
# 키 : 192
# BMI : 21.70138888888889
# 결과 : 정상 체중
#
# 이름 : 마사
# 몸무게 : 48
# 키 : 143
# BMI : 23.47303046603746
# 결과 : 정상 체중
#
# 이름 : 사마
# 몸무게 : 87
# 키 : 151
# BMI : 38.15622121836761
# 결과 : 과체중
#
# 이름 : 하다
# 몸무게 : 64
# 키 : 176
# BMI : 20.66115702479339
# 결과 : 정상 체중
#
# 이름 : 마사
# 몸무게 : 42
# 키 : 158
# BMI : 16.82422688671687
# 결과 : 저체중
#
# 이름 : 바타
# 몸무게 : 80
# 키 : 179
# BMI : 24.968009737523797
# 결과 : 정상 체중
#
# 이름 : 다사
# 몸무게 : 76
# 키 : 150
# BMI : 33.77777777777778
# 결과 : 과체중
#
# 이름 : 자사
# 몸무게 : 56
# 키 : 180
# BMI : 17.28395061728395
# 결과 : 저체중
#
# 이름 : 하사
# 몸무게 : 80
# 키 : 199
# BMI : 20.201510062877198
# 결과 : 정상 체중
#
# 이름 : 바타
# 몸무게 : 57
# 키 : 195
# BMI : 14.990138067061144
# 결과 : 저체중
#
# 이름 : 라자
# 몸무게 : 95
# 키 : 150
# BMI : 42.22222222222222
# 결과 : 과체중
#
# 이름 : 가라
# 몸무게 : 56
# 키 : 164
# BMI : 20.820939916716245
# 결과 : 정상 체중
#
# 이름 : 다바
# 몸무게 : 56
# 키 : 154
# BMI : 23.61275088547816
# 결과 : 정상 체중
#
# 이름 : 아다
# 몸무게 : 79
# 키 : 199
# BMI : 19.948991187091234
# 결과 : 정상 체중
#
# 이름 : 차하
# 몸무게 : 55
# 키 : 176
# BMI : 17.75568181818182
# 결과 : 저체중
#
# 이름 : 타다
# 몸무게 : 44
# 키 : 143
# BMI : 21.516944593867674
# 결과 : 정상 체중
#
# 이름 : 다라
# 몸무게 : 85
# 키 : 162
# BMI : 32.38835543362292
# 결과 : 과체중
#
# 이름 : 바아
# 몸무게 : 79
# 키 : 183
# BMI : 23.589835468362743
# 결과 : 정상 체중
#
# 이름 : 자다
# 몸무게 : 78
# 키 : 148
# BMI : 35.60993425858291
# 결과 : 과체중
#
# 이름 : 파하
# 몸무게 : 90
# 키 : 168
# BMI : 31.88775510204082
# 결과 : 과체중
#
# 이름 : 차다
# 몸무게 : 41
# 키 : 183
# BMI : 12.242826002568005
# 결과 : 저체중
#
# 이름 : 마나
# 몸무게 : 51
# 키 : 142
# BMI : 25.29260067446935
# 결과 : 과체중
#
# 이름 : 타아
# 몸무게 : 50
# 키 : 157
# BMI : 20.28479857195018
# 결과 : 정상 체중
#
# 이름 : 차카
# 몸무게 : 45
# 키 : 193
# BMI : 12.080861231173992
# 결과 : 저체중
#
# 이름 : 카자
# 몸무게 : 96
# 키 : 185
# BMI : 28.04967129291453
# 결과 : 과체중
#
# 이름 : 파파
# 몸무게 : 90
# 키 : 187
# BMI : 25.737081414967538
# 결과 : 과체중
#
# 이름 : 나나
# 몸무게 : 86
# 키 : 197
# BMI : 22.159808291891057
# 결과 : 정상 체중
#
# 이름 : 가파
# 몸무게 : 47
# 키 : 183
# BMI : 14.034459076114544
# 결과 : 저체중
#
# 이름 : 라나
# 몸무게 : 63
# 키 : 165
# BMI : 23.140495867768596
# 결과 : 정상 체중
#
# 이름 : 나다
# 몸무게 : 54
# 키 : 184
# BMI : 15.949905482041586
# 결과 : 저체중
#
# 이름 : 가차
# 몸무게 : 55
# 키 : 197
# BMI : 14.171970419232652
# 결과 : 저체중
#
# 이름 : 파나
# 몸무게 : 44
# 키 : 155
# BMI : 18.314255983350673
# 결과 : 저체중
#
# 이름 : 차카
# 몸무게 : 43
# 키 : 177
# BMI : 13.725302435443199
# 결과 : 저체중
#
# 이름 : 나자
# 몸무게 : 85
# 키 : 160
# BMI : 33.20312499999999
# 결과 : 과체중
#
# 이름 : 자차
# 몸무게 : 44
# 키 : 177
# BMI : 14.044495515337227
# 결과 : 저체중
#
# 이름 : 타아
# 몸무게 : 93
# 키 : 140
# BMI : 47.44897959183674
# 결과 : 과체중
#
# 이름 : 다가
# 몸무게 : 73
# 키 : 176
# BMI : 23.56663223140496
# 결과 : 정상 체중
#
# 이름 : 나카
# 몸무게 : 43
# 키 : 197
# BMI : 11.079904145945529
# 결과 : 저체중
#
# 이름 : 카사
# 몸무게 : 93
# 키 : 165
# BMI : 34.159779614325075
# 결과 : 과체중
#
# 이름 : 하파
# 몸무게 : 46
# 키 : 169
# BMI : 16.105878645705683
# 결과 : 저체중
#
# 이름 : 마나
# 몸무게 : 73
# 키 : 162
# BMI : 27.815881725346742
# 결과 : 과체중
#
# 이름 : 바아
# 몸무게 : 99
# 키 : 175
# BMI : 32.326530612244895
# 결과 : 과체중
#
# 이름 : 파바
# 몸무게 : 77
# 키 : 146
# BMI : 36.12310001876525
# 결과 : 과체중
#
# 이름 : 나사
# 몸무게 : 50
# 키 : 184
# BMI : 14.768431001890358
# 결과 : 저체중
#
# 이름 : 가하
# 몸무게 : 63
# 키 : 158
# BMI : 25.236340330075304
# 결과 : 과체중
#
# 이름 : 파차
# 몸무게 : 44
# 키 : 158
# BMI : 17.625380547989103
# 결과 : 저체중
#
# 이름 : 타타
# 몸무게 : 68
# 키 : 140
# BMI : 34.693877551020414
# 결과 : 과체중
#
# 이름 : 자아
# 몸무게 : 94
# 키 : 176
# BMI : 30.34607438016529
# 결과 : 과체중
#
# 이름 : 차아
# 몸무게 : 86
# 키 : 191
# BMI : 23.573915188728378
# 결과 : 정상 체중
#
# 이름 : 타바
# 몸무게 : 74
# 키 : 190
# BMI : 20.498614958448755
# 결과 : 정상 체중
#
# 이름 : 타타
# 몸무게 : 96
# 키 : 178
# BMI : 30.299204645878046
# 결과 : 과체중
#
# 이름 : 하차
# 몸무게 : 77
# 키 : 149
# BMI : 34.68312238187469
# 결과 : 과체중
#
# 이름 : 차다
# 몸무게 : 51
# 키 : 189
# BMI : 14.277315864617453
# 결과 : 저체중
#
# 이름 : 하가
# 몸무게 : 56
# 키 : 178
# BMI : 17.67453604342886
# 결과 : 저체중
#
# 이름 : 카가
# 몸무게 : 49
# 키 : 160
# BMI : 19.140624999999996
# 결과 : 정상 체중
#
# 이름 : 하다
# 몸무게 : 41
# 키 : 195
# BMI : 10.782380013149245
# 결과 : 저체중
#
# 이름 : 나라
# 몸무게 : 57
# 키 : 145
# BMI : 27.110582639714625
# 결과 : 과체중
#
# 이름 : 나라
# 몸무게 : 90
# 키 : 179
# BMI : 28.089010954714272
# 결과 : 과체중
#
# 이름 : 아하
# 몸무게 : 57
# 키 : 155
# BMI : 23.725286160249738
# 결과 : 정상 체중
#
# 이름 : 카타
# 몸무게 : 82
# 키 : 178
# BMI : 25.88057063502083
# 결과 : 과체중
#
# 이름 : 나나
# 몸무게 : 52
# 키 : 157
# BMI : 21.096190514828187
# 결과 : 정상 체중
#
# 이름 : 나바
# 몸무게 : 95
# 키 : 163
# BMI : 35.75595618954421
# 결과 : 과체중
#
# 이름 : 바카
# 몸무게 : 43
# 키 : 187
# BMI : 12.296605564928935
# 결과 : 저체중
#
# 이름 : 다마
# 몸무게 : 84
# 키 : 162
# BMI : 32.00731595793324
# 결과 : 과체중
#
# 이름 : 마라
# 몸무게 : 73
# 키 : 182
# BMI : 22.03840115928028
# 결과 : 정상 체중
#
# 이름 : 파하
# 몸무게 : 45
# 키 : 166
# BMI : 16.330381768036002
# 결과 : 저체중
#
# 이름 : 하하
# 몸무게 : 72
# 키 : 169
# BMI : 25.209201358495854
# 결과 : 과체중
#
# 이름 : 아카
# 몸무게 : 57
# 키 : 158
# BMI : 22.832879346258608
# 결과 : 정상 체중
#
# 이름 : 마하
# 몸무게 : 84
# 키 : 161
# BMI : 32.40615716986227
# 결과 : 과체중
#
# 이름 : 하아
# 몸무게 : 91
# 키 : 153
# BMI : 38.87393737451408
# 결과 : 과체중
#
# 이름 : 아파
# 몸무게 : 78
# 키 : 159
# BMI : 30.853209920493647
# 결과 : 과체중
#
# 이름 : 차차
# 몸무게 : 43
# 키 : 162
# BMI : 16.384697454656298
# 결과 : 저체중
#
# 이름 : 자바
# 몸무게 : 83
# 키 : 166
# BMI : 30.120481927710845
# 결과 : 과체중
#
# 이름 : 자카
# 몸무게 : 43
# 키 : 190
# BMI : 11.911357340720222
# 결과 : 저체중
#
# 이름 : 라다
# 몸무게 : 70
# 키 : 154
# BMI : 29.515938606847698
# 결과 : 과체중
#
# 이름 : 하마
# 몸무게 : 45
# 키 : 184
# BMI : 13.291587901701323
# 결과 : 저체중
#
# 이름 : 라마
# 몸무게 : 43
# 키 : 180
# BMI : 13.271604938271604
# 결과 : 저체중
#
# 이름 : 자다
# 몸무게 : 58
# 키 : 187
# BMI : 16.586119134090193
# 결과 : 저체중
#
# 이름 : 아아
# 몸무게 : 57
# 키 : 174
# BMI : 18.826793499801823
# 결과 : 정상 체중
#
# 이름 : 아차
# 몸무게 : 88
# 키 : 168
# BMI : 31.17913832199547
# 결과 : 과체중
#
# 이름 : 파자
# 몸무게 : 44
# 키 : 158
# BMI : 17.625380547989103
# 결과 : 저체중
#
# 이름 : 파자
# 몸무게 : 85
# 키 : 166
# BMI : 30.84627667295689
# 결과 : 과체중
#
# 이름 : 나차
# 몸무게 : 82
# 키 : 171
# BMI : 28.042816593139772
# 결과 : 과체중
#
# 이름 : 차하
# 몸무게 : 64
# 키 : 167
# BMI : 22.948115744558788
# 결과 : 정상 체중
#
# 이름 : 하다
# 몸무게 : 84
# 키 : 163
# BMI : 31.615792841281195
# 결과 : 과체중
#
# 이름 : 라바
# 몸무게 : 78
# 키 : 174
# BMI : 25.762980578676178
# 결과 : 과체중
#
# 이름 : 파타
# 몸무게 : 55
# 키 : 185
# BMI : 16.070124178232284
# 결과 : 저체중
#
# 이름 : 다타
# 몸무게 : 97
# 키 : 175
# BMI : 31.6734693877551
# 결과 : 과체중
#
# 이름 : 차바
# 몸무게 : 52
# 키 : 194
# BMI : 13.81655861409289
# 결과 : 저체중
#
# 이름 : 자차
# 몸무게 : 90
# 키 : 149
# BMI : 40.53871447232107
# 결과 : 과체중
#
# 이름 : 마자
# 몸무게 : 84
# 키 : 154
# BMI : 35.41912632821724
# 결과 : 과체중
#
# 이름 : 라마
# 몸무게 : 53
# 키 : 144
# BMI : 25.559413580246915
# 결과 : 과체중
#
# 이름 : 다다
# 몸무게 : 56
# 키 : 196
# BMI : 14.57725947521866
# 결과 : 저체중
#
# 이름 : 타파
# 몸무게 : 90
# 키 : 176
# BMI : 29.054752066115704
# 결과 : 과체중
#
# 이름 : 가자
# 몸무게 : 92
# 키 : 154
# BMI : 38.792376454714116
# 결과 : 과체중
#
# 이름 : 자타
# 몸무게 : 70
# 키 : 150
# BMI : 31.11111111111111
# 결과 : 과체중
#
# 이름 : 아카
# 몸무게 : 78
# 키 : 182
# BMI : 23.54788069073783
# 결과 : 정상 체중
#
# 이름 : 타카
# 몸무게 : 95
# 키 : 174
# BMI : 31.37798916633637
# 결과 : 과체중
#
# 이름 : 카파
# 몸무게 : 70
# 키 : 175
# BMI : 22.857142857142858
# 결과 : 정상 체중
#
# 이름 : 카카
# 몸무게 : 60
# 키 : 165
# BMI : 22.03856749311295
# 결과 : 정상 체중
#
# 이름 : 자타
# 몸무게 : 78
# 키 : 146
# BMI : 36.59223118784013
# 결과 : 과체중
#
# 이름 : 다자
# 몸무게 : 80
# 키 : 180
# BMI : 24.691358024691358
# 결과 : 정상 체중
#
# 이름 : 다카
# 몸무게 : 47
# 키 : 177
# BMI : 15.00207475501931
# 결과 : 저체중
#
# 이름 : 바사
# 몸무게 : 79
# 키 : 189
# BMI : 22.11584222166233
# 결과 : 정상 체중
#
# 이름 : 다파
# 몸무게 : 77
# 키 : 177
# BMI : 24.577867151840145
# 결과 : 정상 체중
#
# 이름 : 타가
# 몸무게 : 62
# 키 : 161
# BMI : 23.9188302920412
# 결과 : 정상 체중
#
# 이름 : 파라
# 몸무게 : 97
# 키 : 182
# BMI : 29.283902910276534
# 결과 : 과체중
#
# 이름 : 타바
# 몸무게 : 59
# 키 : 188
# BMI : 16.693073789044817
# 결과 : 저체중
#
# 이름 : 나바
# 몸무게 : 72
# 키 : 166
# BMI : 26.1286108288576
# 결과 : 과체중
#
# 이름 : 마파
# 몸무게 : 48
# 키 : 166
# BMI : 17.419073885905068
# 결과 : 저체중
#
# 이름 : 하차
# 몸무게 : 57
# 키 : 196
# BMI : 14.83756768013328
# 결과 : 저체중
#
# 이름 : 차사
# 몸무게 : 83
# 키 : 173
# BMI : 27.732299776136855
# 결과 : 과체중
#
# 이름 : 바자
# 몸무게 : 63
# 키 : 192
# BMI : 17.08984375
# 결과 : 저체중
#
# 이름 : 차타
# 몸무게 : 61
# 키 : 140
# BMI : 31.12244897959184
# 결과 : 과체중
#
# 이름 : 파가
# 몸무게 : 46
# 키 : 159
# BMI : 18.19548277362446
# 결과 : 저체중
#
# 이름 : 아자
# 몸무게 : 75
# 키 : 163
# BMI : 28.228386465429637
# 결과 : 과체중
#
# 이름 : 자자
# 몸무게 : 56
# 키 : 179
# BMI : 17.477606816266658
# 결과 : 저체중
#
# 이름 : 가나
# 몸무게 : 60
# 키 : 175
# BMI : 19.591836734693878
# 결과 : 정상 체중
#
# 이름 : 파아
# 몸무게 : 49
# 키 : 167
# BMI : 17.569651116927822
# 결과 : 저체중
#
# 이름 : 차파
# 몸무게 : 83
# 키 : 181
# BMI : 25.33500198406642
# 결과 : 과체중
#
# 이름 : 사파
# 몸무게 : 95
# 키 : 143
# BMI : 46.457039464032476
# 결과 : 과체중
#
# 이름 : 바다
# 몸무게 : 83
# 키 : 166
# BMI : 30.120481927710845
# 결과 : 과체중
#
# 이름 : 나나
# 몸무게 : 93
# 키 : 165
# BMI : 34.159779614325075
# 결과 : 과체중
#
# 이름 : 다라
# 몸무게 : 70
# 키 : 176
# BMI : 22.59814049586777
# 결과 : 정상 체중
#
# 이름 : 타다
# 몸무게 : 97
# 키 : 191
# BMI : 26.589183410542475
# 결과 : 과체중
#
# 이름 : 카차
# 몸무게 : 80
# 키 : 190
# BMI : 22.1606648199446
# 결과 : 정상 체중
#
# 이름 : 타다
# 몸무게 : 48
# 키 : 147
# BMI : 22.212966819380814
# 결과 : 정상 체중
#
# 이름 : 아타
# 몸무게 : 86
# 키 : 194
# BMI : 22.85046232330747
# 결과 : 정상 체중
#
# 이름 : 사아
# 몸무게 : 63
# 키 : 182
# BMI : 19.01944209636517
# 결과 : 정상 체중
#
# 이름 : 사가
# 몸무게 : 99
# 키 : 148
# BMI : 45.19722425127831
# 결과 : 과체중
#
# 이름 : 타나
# 몸무게 : 77
# 키 : 157
# BMI : 31.238589800803275
# 결과 : 과체중
#
# 이름 : 라바
# 몸무게 : 76
# 키 : 170
# BMI : 26.29757785467128
# 결과 : 과체중
#
# 이름 : 라라
# 몸무게 : 77
# 키 : 167
# BMI : 27.60945175517229
# 결과 : 과체중
#
# 이름 : 가나
# 몸무게 : 76
# 키 : 162
# BMI : 28.959000152415786
# 결과 : 과체중
#
# 이름 : 다차
# 몸무게 : 71
# 키 : 155
# BMI : 29.552549427679498
# 결과 : 과체중
#
# 이름 : 파나
# 몸무게 : 49
# 키 : 158
# BMI : 19.62826470116968
# 결과 : 정상 체중
#
# 이름 : 자파
# 몸무게 : 93
# 키 : 168
# BMI : 32.95068027210885
# 결과 : 과체중
#
# 이름 : 다사
# 몸무게 : 97
# 키 : 172
# BMI : 32.787993510005414
# 결과 : 과체중
#
# 이름 : 가파
# 몸무게 : 93
# 키 : 177
# BMI : 29.68495643014459
# 결과 : 과체중
#
# 이름 : 다나
# 몸무게 : 81
# 키 : 188
# BMI : 22.917609778180175
# 결과 : 정상 체중
#
# 이름 : 다바
# 몸무게 : 91
# 키 : 168
# BMI : 32.242063492063494
# 결과 : 과체중
#
# 이름 : 가라
# 몸무게 : 49
# 키 : 144
# BMI : 23.630401234567902
# 결과 : 정상 체중
#
# 이름 : 파라
# 몸무게 : 63
# 키 : 143
# BMI : 30.80835248667417
# 결과 : 과체중
#
# 이름 : 파타
# 몸무게 : 89
# 키 : 179
# BMI : 27.776910832995224
# 결과 : 과체중
#
# 이름 : 차아
# 몸무게 : 95
# 키 : 176
# BMI : 30.668904958677686
# 결과 : 과체중
#
# 이름 : 타자
# 몸무게 : 86
# 키 : 162
# BMI : 32.769394909312595
# 결과 : 과체중
#
# 이름 : 라마
# 몸무게 : 62
# 키 : 143
# BMI : 30.319331018631722
# 결과 : 과체중
#
# 이름 : 차자
# 몸무게 : 82
# 키 : 196
# BMI : 21.345272802998753
# 결과 : 정상 체중
#
# 이름 : 다바
# 몸무게 : 62
# 키 : 174
# BMI : 20.478266613819528
# 결과 : 정상 체중
#
# 이름 : 마자
# 몸무게 : 62
# 키 : 167
# BMI : 22.230987127541326
# 결과 : 정상 체중
#
# 이름 : 라사
# 몸무게 : 89
# 키 : 174
# BMI : 29.396221429515126
# 결과 : 과체중
#
# 이름 : 다하
# 몸무게 : 87
# 키 : 144
# BMI : 41.95601851851852
# 결과 : 과체중
#
# 이름 : 카사
# 몸무게 : 98
# 키 : 197
# BMI : 25.25187456517818
# 결과 : 과체중
#
# 이름 : 다아
# 몸무게 : 69
# 키 : 195
# BMI : 18.14595660749507
# 결과 : 저체중
#
# 이름 : 라라
# 몸무게 : 57
# 키 : 166
# BMI : 20.685150239512268
# 결과 : 정상 체중
#
# 이름 : 하아
# 몸무게 : 52
# 키 : 166
# BMI : 18.870663376397157
# 결과 : 정상 체중
#
# 이름 : 하자
# 몸무게 : 87
# 키 : 161
# BMI : 33.56351992592878
# 결과 : 과체중
#
# 이름 : 사사
# 몸무게 : 69
# 키 : 161
# BMI : 26.61934338952972
# 결과 : 과체중
#
# 이름 : 차아
# 몸무게 : 52
# 키 : 173
# BMI : 17.374452871796585
# 결과 : 저체중
#
# 이름 : 자아
# 몸무게 : 42
# 키 : 156
# BMI : 17.258382642998026
# 결과 : 저체중
#
# 이름 : 카차
# 몸무게 : 41
# 키 : 175
# BMI : 13.387755102040817
# 결과 : 저체중
#
# 이름 : 바사
# 몸무게 : 60
# 키 : 157
# BMI : 24.341758286340216
# 결과 : 정상 체중
#
# 이름 : 다아
# 몸무게 : 87
# 키 : 188
# BMI : 24.615210502489816
# 결과 : 정상 체중
#
# 이름 : 카자
# 몸무게 : 74
# 키 : 166
# BMI : 26.854405574103644
# 결과 : 과체중
#
# 이름 : 하다
# 몸무게 : 56
# 키 : 169
# BMI : 19.607156612163443
# 결과 : 정상 체중
#
# 이름 : 다아
# 몸무게 : 83
# 키 : 170
# BMI : 28.719723183391007
# 결과 : 과체중
#
# 이름 : 하바
# 몸무게 : 93
# 키 : 140
# BMI : 47.44897959183674
# 결과 : 과체중
#
# 이름 : 라사
# 몸무게 : 83
# 키 : 141
# BMI : 41.74840299783714
# 결과 : 과체중
#
# 이름 : 타카
# 몸무게 : 88
# 키 : 192
# BMI : 23.87152777777778
# 결과 : 정상 체중
#
# 이름 : 다사
# 몸무게 : 90
# 키 : 143
# BMI : 44.011932123820245
# 결과 : 과체중
#
# 이름 : 바나
# 몸무게 : 95
# 키 : 142
# BMI : 47.113667923031144
# 결과 : 과체중
#
# 이름 : 바라
# 몸무게 : 47
# 키 : 199
# BMI : 11.868387161940355
# 결과 : 저체중
#
# 이름 : 나차
# 몸무게 : 87
# 키 : 163
# BMI : 32.74492829989838
# 결과 : 과체중
#
# 이름 : 타사
# 몸무게 : 82
# 키 : 157
# BMI : 33.26706965799829
# 결과 : 과체중
#
# 이름 : 바가
# 몸무게 : 87
# 키 : 191
# BMI : 23.84803048162057
# 결과 : 정상 체중
#
# 이름 : 타타
# 몸무게 : 70
# 키 : 190
# BMI : 19.390581717451525
# 결과 : 정상 체중
#
# 이름 : 사나
# 몸무게 : 72
# 키 : 148
# BMI : 32.87070854638422
# 결과 : 과체중
#
# 이름 : 하자
# 몸무게 : 94
# 키 : 160
# BMI : 36.71874999999999
# 결과 : 과체중
#
# 이름 : 다차
# 몸무게 : 74
# 키 : 184
# BMI : 21.85727788279773
# 결과 : 정상 체중
#
# 이름 : 가파
# 몸무게 : 50
# 키 : 149
# BMI : 22.52150804017837
# 결과 : 정상 체중
#
# 이름 : 하다
# 몸무게 : 62
# 키 : 193
# BMI : 16.64474214072861
# 결과 : 저체중
#
# 이름 : 타아
# 몸무게 : 80
# 키 : 172
# BMI : 27.041644131963228
# 결과 : 과체중
#
# 이름 : 다다
# 몸무게 : 46
# 키 : 183
# BMI : 13.735853563856788
# 결과 : 저체중
#
# 이름 : 가카
# 몸무게 : 57
# 키 : 188
# BMI : 16.127206880941603
# 결과 : 저체중
#
# 이름 : 하나
# 몸무게 : 51
# 키 : 172
# BMI : 17.239048134126556
# 결과 : 저체중
#
# 이름 : 하카
# 몸무게 : 60
# 키 : 189
# BMI : 16.79684219366759
# 결과 : 저체중
#
# 이름 : 사타
# 몸무게 : 46
# 키 : 182
# BMI : 13.88721168940949
# 결과 : 저체중
#
# 이름 : 바카
# 몸무게 : 88
# 키 : 145
# BMI : 41.85493460166468
# 결과 : 과체중
#
# 이름 : 자다
# 몸무게 : 45
# 키 : 190
# BMI : 12.465373961218837
# 결과 : 저체중
#
# 이름 : 카카
# 몸무게 : 83
# 키 : 164
# BMI : 30.859607376561577
# 결과 : 과체중
#
# 이름 : 파바
# 몸무게 : 85
# 키 : 150
# BMI : 37.77777777777778
# 결과 : 과체중
#
# 이름 : 바하
# 몸무게 : 51
# 키 : 167
# BMI : 18.286779733945284
# 결과 : 저체중
#
# 이름 : 가아
# 몸무게 : 52
# 키 : 145
# BMI : 24.732461355529132
# 결과 : 정상 체중
#
# 이름 : 자파
# 몸무게 : 45
# 키 : 144
# BMI : 21.70138888888889
# 결과 : 정상 체중
#
# 이름 : 다바
# 몸무게 : 59
# 키 : 158
# BMI : 23.634033007530842
# 결과 : 정상 체중
#
# 이름 : 다타
# 몸무게 : 60
# 키 : 152
# BMI : 25.969529085872576
# 결과 : 과체중
#
# 이름 : 자파
# 몸무게 : 59
# 키 : 191
# BMI : 16.17280228063924
# 결과 : 저체중
#
# 이름 : 사가
# 몸무게 : 51
# 키 : 167
# BMI : 18.286779733945284
# 결과 : 저체중
#
# 이름 : 가마
# 몸무게 : 55
# 키 : 188
# BMI : 15.56133997283839
# 결과 : 저체중
#
# 이름 : 라아
# 몸무게 : 85
# 키 : 183
# BMI : 25.381468541909282
# 결과 : 과체중
#
# 이름 : 바나
# 몸무게 : 54
# 키 : 183
# BMI : 16.124697661918837
# 결과 : 저체중
#
# 이름 : 나나
# 몸무게 : 99
# 키 : 165
# BMI : 36.36363636363637
# 결과 : 과체중
#
# 이름 : 가바
# 몸무게 : 98
# 키 : 149
# BMI : 44.14215575874961
# 결과 : 과체중
#
# 이름 : 나다
# 몸무게 : 78
# 키 : 178
# BMI : 24.61810377477591
# 결과 : 정상 체중
#
# 이름 : 바자
# 몸무게 : 61
# 키 : 149
# BMI : 27.476239809017613
# 결과 : 과체중
#
# 이름 : 차라
# 몸무게 : 81
# 키 : 192
# BMI : 21.97265625
# 결과 : 정상 체중
#
# 이름 : 파나
# 몸무게 : 56
# 키 : 155
# BMI : 23.309053069719038
# 결과 : 정상 체중
#
# 이름 : 차하
# 몸무게 : 78
# 키 : 166
# BMI : 28.305995064595734
# 결과 : 과체중
#
# 이름 : 나카
# 몸무게 : 95
# 키 : 172
# BMI : 32.11195240670633
# 결과 : 과체중
#
# 이름 : 나하
# 몸무게 : 45
# 키 : 166
# BMI : 16.330381768036002
# 결과 : 저체중
#
# 이름 : 가자
# 몸무게 : 72
# 키 : 180
# BMI : 22.22222222222222
# 결과 : 정상 체중
#
# 이름 : 바다
# 몸무게 : 91
# 키 : 165
# BMI : 33.425160697887975
# 결과 : 과체중
#
# 이름 : 아자
# 몸무게 : 57
# 키 : 185
# BMI : 16.654492330168004
# 결과 : 저체중
#
# 이름 : 사다
# 몸무게 : 64
# 키 : 144
# BMI : 30.8641975308642
# 결과 : 과체중
#
# 이름 : 하하
# 몸무게 : 88
# 키 : 176
# BMI : 28.40909090909091
# 결과 : 과체중
#
# 이름 : 사자
# 몸무게 : 58
# 키 : 162
# BMI : 22.10028959000152
# 결과 : 정상 체중
#
# 이름 : 다다
# 몸무게 : 41
# 키 : 193
# BMI : 11.007006899514082
# 결과 : 저체중
#
# 이름 : 다타
# 몸무게 : 94
# 키 : 147
# BMI : 43.50039335462076
# 결과 : 과체중
#
# 이름 : 다가
# 몸무게 : 76
# 키 : 150
# BMI : 33.77777777777778
# 결과 : 과체중
#
# 이름 : 자아
# 몸무게 : 86
# 키 : 141
# BMI : 43.25738141944571
# 결과 : 과체중
#
# 이름 : 마바
# 몸무게 : 70
# 키 : 163
# BMI : 26.346494034400994
# 결과 : 과체중
#
# 이름 : 사가
# 몸무게 : 75
# 키 : 192
# BMI : 20.345052083333332
# 결과 : 정상 체중
#
# 이름 : 파사
# 몸무게 : 64
# 키 : 169
# BMI : 22.40817898532965
# 결과 : 정상 체중
#
# 이름 : 아차
# 몸무게 : 76
# 키 : 195
# BMI : 19.986850756081527
# 결과 : 정상 체중
#
# 이름 : 다바
# 몸무게 : 77
# 키 : 157
# BMI : 31.238589800803275
# 결과 : 과체중
#
# 이름 : 파사
# 몸무게 : 85
# 키 : 145
# BMI : 40.428061831153386
# 결과 : 과체중
#
# 이름 : 바아
# 몸무게 : 63
# 키 : 161
# BMI : 24.3046178773967
# 결과 : 정상 체중
#
# 이름 : 바타
# 몸무게 : 82
# 키 : 154
# BMI : 34.57581379659302
# 결과 : 과체중
#
# 이름 : 라차
# 몸무게 : 78
# 키 : 149
# BMI : 35.13355254267826
# 결과 : 과체중
#
# 이름 : 차하
# 몸무게 : 98
# 키 : 164
# BMI : 36.43664485425343
# 결과 : 과체중
#
# 이름 : 바다
# 몸무게 : 47
# 키 : 179
# BMI : 14.66870572079523
# 결과 : 저체중
#
# 이름 : 아아
# 몸무게 : 60
# 키 : 144
# BMI : 28.935185185185187
# 결과 : 과체중
#
# 이름 : 타사
# 몸무게 : 87
# 키 : 158
# BMI : 34.85018426534209
# 결과 : 과체중
#
# 이름 : 타카
# 몸무게 : 57
# 키 : 158
# BMI : 22.832879346258608
# 결과 : 정상 체중
#
# 이름 : 아카
# 몸무게 : 81
# 키 : 190
# BMI : 22.437673130193907
# 결과 : 정상 체중
#
# 이름 : 차다
# 몸무게 : 98
# 키 : 192
# BMI : 26.58420138888889
# 결과 : 과체중
#
# 이름 : 하바
# 몸무게 : 55
# 키 : 157
# BMI : 22.313278429145196
# 결과 : 정상 체중
#
# 이름 : 타마
# 몸무게 : 71
# 키 : 181
# BMI : 21.672110130948383
# 결과 : 정상 체중
#
# 이름 : 가가
# 몸무게 : 46
# 키 : 199
# BMI : 11.61586828615439
# 결과 : 저체중
#
# 이름 : 아바
# 몸무게 : 61
# 키 : 168
# BMI : 21.612811791383223
# 결과 : 정상 체중
#
# 이름 : 타가
# 몸무게 : 67
# 키 : 194
# BMI : 17.802104368158147
# 결과 : 저체중
#
# 이름 : 바자
# 몸무게 : 80
# 키 : 192
# BMI : 21.70138888888889
# 결과 : 정상 체중
#
# 이름 : 사파
# 몸무게 : 41
# 키 : 140
# BMI : 20.91836734693878
# 결과 : 정상 체중
#
# 이름 : 라바
# 몸무게 : 95
# 키 : 192
# BMI : 25.770399305555557
# 결과 : 과체중
#
# 이름 : 마파
# 몸무게 : 41
# 키 : 155
# BMI : 17.065556711758582
# 결과 : 저체중
#
# 이름 : 바자
# 몸무게 : 92
# 키 : 161
# BMI : 35.492457852706295
# 결과 : 과체중
#
# 이름 : 가다
# 몸무게 : 52
# 키 : 199
# BMI : 13.130981540870179
# 결과 : 저체중
#
# 이름 : 자다
# 몸무게 : 60
# 키 : 150
# BMI : 26.666666666666668
# 결과 : 과체중
#
# 이름 : 카가
# 몸무게 : 98
# 키 : 153
# BMI : 41.864240249476694
# 결과 : 과체중
#
# 이름 : 바하
# 몸무게 : 44
# 키 : 174
# BMI : 14.532963403355794
# 결과 : 저체중
#
# 이름 : 아마
# 몸무게 : 83
# 키 : 146
# BMI : 38.937887033214494
# 결과 : 과체중
#
# 이름 : 다자
# 몸무게 : 66
# 키 : 192
# BMI : 17.903645833333332
# 결과 : 저체중
#
# 이름 : 타파
# 몸무게 : 75
# 키 : 169
# BMI : 26.25958474843318
# 결과 : 과체중
#
# 이름 : 파하
# 몸무게 : 69
# 키 : 179
# BMI : 21.534908398614277
# 결과 : 정상 체중
#
# 이름 : 바다
# 몸무게 : 76
# 키 : 160
# BMI : 29.687499999999993
# 결과 : 과체중
#
# 이름 : 마카
# 몸무게 : 79
# 키 : 140
# BMI : 40.3061224489796
# 결과 : 과체중
#
# 이름 : 마타
# 몸무게 : 76
# 키 : 166
# BMI : 27.58020031934969
# 결과 : 과체중
#
# 이름 : 가아
# 몸무게 : 79
# 키 : 161
# BMI : 30.477219243084754
# 결과 : 과체중
#
# 이름 : 파차
# 몸무게 : 70
# 키 : 147
# BMI : 32.39390994493036
# 결과 : 과체중
#
# 이름 : 바타
# 몸무게 : 95
# 키 : 199
# BMI : 23.989293199666673
# 결과 : 정상 체중
#
# 이름 : 바가
# 몸무게 : 87
# 키 : 170
# BMI : 30.103806228373706
# 결과 : 과체중
#
# 이름 : 하아
# 몸무게 : 45
# 키 : 190
# BMI : 12.465373961218837
# 결과 : 저체중
#
# 이름 : 나바
# 몸무게 : 58
# 키 : 185
# BMI : 16.946676406135865
# 결과 : 저체중
#
# 이름 : 아아
# 몸무게 : 43
# 키 : 175
# BMI : 14.040816326530612
# 결과 : 저체중
#
# 이름 : 타자
# 몸무게 : 87
# 키 : 184
# BMI : 25.697069943289225
# 결과 : 과체중
#
# 이름 : 차파
# 몸무게 : 96
# 키 : 199
# BMI : 24.24181207545264
# 결과 : 정상 체중
#
# 이름 : 파바
# 몸무게 : 67
# 키 : 199
# BMI : 16.918764677659656
# 결과 : 저체중
#
# 이름 : 파사
# 몸무게 : 42
# 키 : 169
# BMI : 14.705367459122582
# 결과 : 저체중
#
# 이름 : 파나
# 몸무게 : 60
# 키 : 168
# BMI : 21.258503401360546
# 결과 : 정상 체중
#
# 이름 : 타카
# 몸무게 : 57
# 키 : 153
# BMI : 24.34960912469563
# 결과 : 정상 체중
#
# 이름 : 다가
# 몸무게 : 82
# 키 : 166
# BMI : 29.757584555087824
# 결과 : 과체중
#
# 이름 : 파마
# 몸무게 : 89
# 키 : 195
# BMI : 23.405654174884944
# 결과 : 정상 체중
#
# 이름 : 가라
# 몸무게 : 71
# 키 : 154
# BMI : 29.93759487265981
# 결과 : 과체중
#
# 이름 : 파아
# 몸무게 : 53
# 키 : 192
# BMI : 14.37717013888889
# 결과 : 저체중
#
# 이름 : 자사
# 몸무게 : 85
# 키 : 145
# BMI : 40.428061831153386
# 결과 : 과체중
#
# 이름 : 파나
# 몸무게 : 83
# 키 : 151
# BMI : 36.40191219683347
# 결과 : 과체중
#
# 이름 : 사가
# 몸무게 : 68
# 키 : 154
# BMI : 28.67262607522348
# 결과 : 과체중
#
# 이름 : 아마
# 몸무게 : 76
# 키 : 176
# BMI : 24.535123966942148
# 결과 : 정상 체중
#
# 이름 : 바라
# 몸무게 : 54
# 키 : 157
# BMI : 21.907582457706194
# 결과 : 정상 체중
#
# 이름 : 차라
# 몸무게 : 90
# 키 : 188
# BMI : 25.46401086464464
# 결과 : 과체중
#
# 이름 : 타바
# 몸무게 : 98
# 키 : 141
# BMI : 49.29329510587999
# 결과 : 과체중
#
# 이름 : 파가
# 몸무게 : 69
# 키 : 174
# BMI : 22.79032897344431
# 결과 : 정상 체중
#
# 이름 : 바나
# 몸무게 : 80
# 키 : 171
# BMI : 27.358845456721728
# 결과 : 과체중
#
# 이름 : 자카
# 몸무게 : 97
# 키 : 160
# BMI : 37.89062499999999
# 결과 : 과체중
#
# 이름 : 다차
# 몸무게 : 59
# 키 : 169
# BMI : 20.65754000210077
# 결과 : 정상 체중
#
# 이름 : 차마
# 몸무게 : 49
# 키 : 196
# BMI : 12.755102040816327
# 결과 : 저체중
#
# 이름 : 라마
# 몸무게 : 40
# 키 : 187
# BMI : 11.438702851096684
# 결과 : 저체중
#
# 이름 : 사타
# 몸무게 : 48
# 키 : 151
# BMI : 21.051708258409718
# 결과 : 정상 체중
#
# 이름 : 하아
# 몸무게 : 95
# 키 : 144
# BMI : 45.814043209876544
# 결과 : 과체중
#
# 이름 : 파다
# 몸무게 : 50
# 키 : 191
# BMI : 13.705764644609523
# 결과 : 저체중
#
# 이름 : 카차
# 몸무게 : 60
# 키 : 186
# BMI : 17.343045438779047
# 결과 : 저체중
#
# 이름 : 사나
# 몸무게 : 40
# 키 : 147
# BMI : 18.510805682817345
# 결과 : 정상 체중
#
# 이름 : 하타
# 몸무게 : 99
# 키 : 198
# BMI : 25.252525252525253
# 결과 : 과체중
#
# 이름 : 바라
# 몸무게 : 82
# 키 : 159
# BMI : 32.4354258138523
# 결과 : 과체중
#
# 이름 : 아카
# 몸무게 : 44
# 키 : 166
# BMI : 15.967484395412978
# 결과 : 저체중
#
# 이름 : 타사
# 몸무게 : 62
# 키 : 186
# BMI : 17.921146953405014
# 결과 : 저체중
#
# 이름 : 사다
# 몸무게 : 54
# 키 : 169
# BMI : 18.906901018871892
# 결과 : 정상 체중
#
# 이름 : 바자
# 몸무게 : 42
# 키 : 173
# BMI : 14.033211934912625
# 결과 : 저체중
#
# 이름 : 카바
# 몸무게 : 83
# 키 : 169
# BMI : 29.060607121599386
# 결과 : 과체중
#
# 이름 : 다자
# 몸무게 : 45
# 키 : 146
# BMI : 21.110902608369305
# 결과 : 정상 체중
#
# 이름 : 사가
# 몸무게 : 86
# 키 : 157
# BMI : 34.889853543754306
# 결과 : 과체중
#
# 이름 : 다파
# 몸무게 : 75
# 키 : 189
# BMI : 20.99605274208449
# 결과 : 정상 체중
#
# 이름 : 마마
# 몸무게 : 54
# 키 : 143
# BMI : 26.407159274292145
# 결과 : 과체중
#
# 이름 : 카사
# 몸무게 : 42
# 키 : 177
# BMI : 13.406109355549171
# 결과 : 저체중
#
# 이름 : 바다
# 몸무게 : 91
# 키 : 188
# BMI : 25.746944318696244
# 결과 : 과체중
#
# 이름 : 다라
# 몸무게 : 97
# 키 : 196
# BMI : 25.249895876718035
# 결과 : 과체중
#
# 이름 : 마마
# 몸무게 : 62
# 키 : 154
# BMI : 26.14268848035082
# 결과 : 과체중
#
# 이름 : 하바
# 몸무게 : 55
# 키 : 148
# BMI : 25.10956902848795
# 결과 : 과체중
#
# 이름 : 카사
# 몸무게 : 58
# 키 : 142
# BMI : 28.76413410037691
# 결과 : 과체중
#
# 이름 : 파나
# 몸무게 : 65
# 키 : 193
# BMI : 17.450132889473544
# 결과 : 저체중
#
# 이름 : 자가
# 몸무게 : 93
# 키 : 185
# BMI : 27.173119065010955
# 결과 : 과체중
#
# 이름 : 사타
# 몸무게 : 89
# 키 : 164
# BMI : 33.09042236763832
# 결과 : 과체중
#
# 이름 : 마가
# 몸무게 : 54
# 키 : 170
# BMI : 18.68512110726644
# 결과 : 정상 체중
#
# 이름 : 가아
# 몸무게 : 57
# 키 : 146
# BMI : 26.740476637267783
# 결과 : 과체중
#
# 이름 : 라바
# 몸무게 : 66
# 키 : 175
# BMI : 21.551020408163264
# 결과 : 정상 체중
#
# 이름 : 나라
# 몸무게 : 60
# 키 : 180
# BMI : 18.51851851851852
# 결과 : 정상 체중
#
# 이름 : 자바
# 몸무게 : 95
# 키 : 196
# BMI : 24.729279466888798
# 결과 : 정상 체중
#
# 이름 : 자다
# 몸무게 : 56
# 키 : 156
# BMI : 23.011176857330703
# 결과 : 정상 체중
#
# 이름 : 마사
# 몸무게 : 91
# 키 : 172
# BMI : 30.75987020010817
# 결과 : 과체중
#
# 이름 : 하다
# 몸무게 : 86
# 키 : 183
# BMI : 25.680074054167036
# 결과 : 과체중
#
# 이름 : 차바
# 몸무게 : 49
# 키 : 148
# BMI : 22.37034331628926
# 결과 : 정상 체중
#
# 이름 : 하나
# 몸무게 : 53
# 키 : 163
# BMI : 19.94805976890361
# 결과 : 정상 체중
#
# 이름 : 카타
# 몸무게 : 57
# 키 : 168
# BMI : 20.19557823129252
# 결과 : 정상 체중
#
# 이름 : 타사
# 몸무게 : 40
# 키 : 199
# BMI : 10.100755031438599
# 결과 : 저체중
#
# 이름 : 파하
# 몸무게 : 42
# 키 : 183
# BMI : 12.541431514825762
# 결과 : 저체중
#
# 이름 : 가가
# 몸무게 : 71
# 키 : 146
# BMI : 33.30831300431601
# 결과 : 과체중
#
# 이름 : 사아
# 몸무게 : 63
# 키 : 179
# BMI : 19.66230766829999
# 결과 : 정상 체중
#
# 이름 : 아사
# 몸무게 : 62
# 키 : 175
# BMI : 20.244897959183675
# 결과 : 정상 체중
#
# 이름 : 차타
# 몸무게 : 56
# 키 : 160
# BMI : 21.874999999999996
# 결과 : 정상 체중
#
# 이름 : 나하
# 몸무게 : 58
# 키 : 152
# BMI : 25.10387811634349
# 결과 : 과체중
#
# 이름 : 파하
# 몸무게 : 86
# 키 : 175
# BMI : 28.081632653061224
# 결과 : 과체중
#
# 이름 : 타자
# 몸무게 : 75
# 키 : 169
# BMI : 26.25958474843318
# 결과 : 과체중
#
# 이름 : 사아
# 몸무게 : 44
# 키 : 199
# BMI : 11.11083053458246
# 결과 : 저체중
#
# 이름 : 하라
# 몸무게 : 41
# 키 : 158
# BMI : 16.423650056080753
# 결과 : 저체중
#
# 이름 : 아하
# 몸무게 : 90
# 키 : 164
# BMI : 33.462224866151104
# 결과 : 과체중
#
# 이름 : 타바
# 몸무게 : 85
# 키 : 190
# BMI : 23.545706371191137
# 결과 : 정상 체중
#
# 이름 : 파가
# 몸무게 : 87
# 키 : 162
# BMI : 33.15043438500228
# 결과 : 과체중
#
# 이름 : 사파
# 몸무게 : 51
# 키 : 186
# BMI : 14.74158862296219
# 결과 : 저체중
#
# 이름 : 자하
# 몸무게 : 96
# 키 : 197
# BMI : 24.736530186296992
# 결과 : 정상 체중
#
# 이름 : 가라
# 몸무게 : 42
# 키 : 184
# BMI : 12.4054820415879
# 결과 : 저체중
#
# 이름 : 차바
# 몸무게 : 98
# 키 : 152
# BMI : 42.41689750692521
# 결과 : 과체중
#
# 이름 : 하사
# 몸무게 : 72
# 키 : 156
# BMI : 29.585798816568044
# 결과 : 과체중
#
# 이름 : 아자
# 몸무게 : 95
# 키 : 152
# BMI : 41.11842105263158
# 결과 : 과체중
#
# 이름 : 바사
# 몸무게 : 85
# 키 : 163
# BMI : 31.992171327486922
# 결과 : 과체중
#
# 이름 : 나자
# 몸무게 : 89
# 키 : 171
# BMI : 30.436715570602924
# 결과 : 과체중
#
# 이름 : 하나
# 몸무게 : 45
# 키 : 173
# BMI : 15.035584215977813
# 결과 : 저체중
#
# 이름 : 바나
# 몸무게 : 84
# 키 : 156
# BMI : 34.51676528599605
# 결과 : 과체중
#
# 이름 : 사파
# 몸무게 : 53
# 키 : 151
# BMI : 23.244594535327398
# 결과 : 정상 체중
#
# 이름 : 가하
# 몸무게 : 59
# 키 : 189
# BMI : 16.516894823773132
# 결과 : 저체중
#
# 이름 : 차마
# 몸무게 : 45
# 키 : 164
# BMI : 16.731112433075552
# 결과 : 저체중
#
# 이름 : 마차
# 몸무게 : 63
# 키 : 149
# BMI : 28.377100130624747
# 결과 : 과체중
#
# 이름 : 나카
# 몸무게 : 68
# 키 : 148
# BMI : 31.0445580715851
# 결과 : 과체중
#
# 이름 : 차마
# 몸무게 : 86
# 키 : 151
# BMI : 37.71764396298408
# 결과 : 과체중
#
# 이름 : 타카
# 몸무게 : 93
# 키 : 198
# BMI : 23.72206917661463
# 결과 : 정상 체중
#
# 이름 : 자카
# 몸무게 : 70
# 키 : 163
# BMI : 26.346494034400994
# 결과 : 과체중
#
# 이름 : 파마
# 몸무게 : 61
# 키 : 174
# BMI : 20.147971991015986
# 결과 : 정상 체중
#
# 이름 : 차마
# 몸무게 : 99
# 키 : 140
# BMI : 50.51020408163266
# 결과 : 과체중
#
# 이름 : 하마
# 몸무게 : 77
# 키 : 174
# BMI : 25.43268595587264
# 결과 : 과체중
#
# 이름 : 아차
# 몸무게 : 98
# 키 : 191
# BMI : 26.863298703434666
# 결과 : 과체중
#
# 이름 : 다사
# 몸무게 : 74
# 키 : 196
# BMI : 19.2628071636818
# 결과 : 정상 체중
#
# 이름 : 다자
# 몸무게 : 90
# 키 : 171
# BMI : 30.778701138811947
# 결과 : 과체중
#
# 이름 : 차마
# 몸무게 : 82
# 키 : 194
# BMI : 21.787650122223404
# 결과 : 정상 체중
#
# 이름 : 하나
# 몸무게 : 60
# 키 : 151
# BMI : 26.314635323012148
# 결과 : 과체중
#
# 이름 : 다라
# 몸무게 : 95
# 키 : 171
# BMI : 32.488628979857054
# 결과 : 과체중
#
# 이름 : 타카
# 몸무게 : 64
# 키 : 156
# BMI : 26.298487836949374
# 결과 : 과체중
#
# 이름 : 카라
# 몸무게 : 71
# 키 : 190
# BMI : 19.667590027700832
# 결과 : 정상 체중
#
# 이름 : 나사
# 몸무게 : 81
# 키 : 168
# BMI : 28.69897959183674
# 결과 : 과체중
#
# 이름 : 아하
# 몸무게 : 69
# 키 : 175
# BMI : 22.53061224489796
# 결과 : 정상 체중
#
# 이름 : 파하
# 몸무게 : 41
# 키 : 165
# BMI : 15.059687786960517
# 결과 : 저체중
#
# 이름 : 라나
# 몸무게 : 86
# 키 : 194
# BMI : 22.85046232330747
# 결과 : 정상 체중
#
# 이름 : 마아
# 몸무게 : 74
# 키 : 162
# BMI : 28.19692120103642
# 결과 : 과체중
#
# 이름 : 바하
# 몸무게 : 82
# 키 : 173
# BMI : 27.39817568244846
# 결과 : 과체중
#
# 이름 : 라나
# 몸무게 : 61
# 키 : 146
# BMI : 28.61700131356728
# 결과 : 과체중
#
# 이름 : 바다
# 몸무게 : 50
# 키 : 178
# BMI : 15.780835753061481
# 결과 : 저체중
#
# 이름 : 자마
# 몸무게 : 89
# 키 : 169
# BMI : 31.161373901474043
# 결과 : 과체중
#
# 이름 : 파마
# 몸무게 : 71
# 키 : 166
# BMI : 25.76571345623458
# 결과 : 과체중
#
# 이름 : 타나
# 몸무게 : 87
# 키 : 171
# BMI : 29.75274443418488
# 결과 : 과체중
#
# 이름 : 바가
# 몸무게 : 65
# 키 : 149
# BMI : 29.27796045223188
# 결과 : 과체중
#
# 이름 : 다나
# 몸무게 : 47
# 키 : 187
# BMI : 13.440475850038604
# 결과 : 저체중
#
# 이름 : 마나
# 몸무게 : 78
# 키 : 150
# BMI : 34.666666666666664
# 결과 : 과체중
#
# 이름 : 사사
# 몸무게 : 50
# 키 : 159
# BMI : 19.77769866698311
# 결과 : 정상 체중
#
# 이름 : 사자
# 몸무게 : 87
# 키 : 163
# BMI : 32.74492829989838
# 결과 : 과체중
#
# 이름 : 다라
# 몸무게 : 87
# 키 : 161
# BMI : 33.56351992592878
# 결과 : 과체중
#
# 이름 : 차마
# 몸무게 : 43
# 키 : 166
# BMI : 15.604587022789955
# 결과 : 저체중
#
# 이름 : 바사
# 몸무게 : 76
# 키 : 159
# BMI : 30.062101973814325
# 결과 : 과체중
#
# 이름 : 나사
# 몸무게 : 82
# 키 : 172
# BMI : 27.717685235262305
# 결과 : 과체중
#
# 이름 : 바타
# 몸무게 : 79
# 키 : 199
# BMI : 19.948991187091234
# 결과 : 정상 체중
#
# 이름 : 가자
# 몸무게 : 40
# 키 : 194
# BMI : 10.628122010840684
# 결과 : 저체중
#
# 이름 : 나다
# 몸무게 : 96
# 키 : 190
# BMI : 26.59279778393352
# 결과 : 과체중
#
# 이름 : 바카
# 몸무게 : 90
# 키 : 198
# BMI : 22.95684113865932
# 결과 : 정상 체중
#
# 이름 : 다카
# 몸무게 : 83
# 키 : 189
# BMI : 23.23563170124017
# 결과 : 정상 체중
#
# 이름 : 다파
# 몸무게 : 40
# 키 : 166
# BMI : 14.51589490492089
# 결과 : 저체중
#
# 이름 : 가가
# 몸무게 : 93
# 키 : 188
# BMI : 26.312811226799457
# 결과 : 과체중
#
# 이름 : 하카
# 몸무게 : 54
# 키 : 182
# BMI : 16.302378939741576
# 결과 : 저체중
#
# 이름 : 다바
# 몸무게 : 98
# 키 : 156
# BMI : 40.269559500328725
# 결과 : 과체중
#
# 이름 : 다나
# 몸무게 : 78
# 키 : 154
# BMI : 32.889188733344575
# 결과 : 과체중
#
# 이름 : 카가
# 몸무게 : 54
# 키 : 189
# BMI : 15.117157974300833
# 결과 : 저체중
#
# 이름 : 라가
# 몸무게 : 83
# 키 : 141
# BMI : 41.74840299783714
# 결과 : 과체중
#
# 이름 : 파파
# 몸무게 : 99
# 키 : 178
# BMI : 31.246054791061734
# 결과 : 과체중
#
# 이름 : 자파
# 몸무게 : 80
# 키 : 177
# BMI : 25.53544639152223
# 결과 : 과체중
#
# 이름 : 바자
# 몸무게 : 98
# 키 : 160
# BMI : 38.28124999999999
# 결과 : 과체중
#
# 이름 : 카라
# 몸무게 : 56
# 키 : 199
# BMI : 14.141057044014039
# 결과 : 저체중
#
# 이름 : 파바
# 몸무게 : 75
# 키 : 168
# BMI : 26.573129251700685
# 결과 : 과체중
#
# 이름 : 가아
# 몸무게 : 67
# 키 : 195
# BMI : 17.61998685075608
# 결과 : 저체중
#
# 이름 : 가바
# 몸무게 : 83
# 키 : 181
# BMI : 25.33500198406642
# 결과 : 과체중
#
# 이름 : 나자
# 몸무게 : 57
# 키 : 180
# BMI : 17.59259259259259
# 결과 : 저체중
#
# 이름 : 차사
# 몸무게 : 98
# 키 : 179
# BMI : 30.585811928466654
# 결과 : 과체중
#
# 이름 : 사타
# 몸무게 : 53
# 키 : 188
# BMI : 14.995473064735176
# 결과 : 저체중
#
# 이름 : 가다
# 몸무게 : 68
# 키 : 156
# BMI : 27.94214332675871
# 결과 : 과체중
#
# 이름 : 가가
# 몸무게 : 90
# 키 : 184
# BMI : 26.583175803402646
# 결과 : 과체중
#
# 이름 : 차자
# 몸무게 : 89
# 키 : 145
# BMI : 42.33055885850178
# 결과 : 과체중
#
# 이름 : 자라
# 몸무게 : 59
# 키 : 175
# BMI : 19.26530612244898
# 결과 : 정상 체중
#
# 이름 : 하나
# 몸무게 : 97
# 키 : 166
# BMI : 35.20104514443316
# 결과 : 과체중
#
# 이름 : 카카
# 몸무게 : 54
# 키 : 142
# BMI : 26.78040071414402
# 결과 : 과체중
#
# 이름 : 라차
# 몸무게 : 99
# 키 : 199
# BMI : 24.999368702810536
# 결과 : 정상 체중
#
# 이름 : 아하
# 몸무게 : 85
# 키 : 147
# BMI : 39.33546207598686
# 결과 : 과체중
#
# 이름 : 라마
# 몸무게 : 57
# 키 : 184
# BMI : 16.836011342155007
# 결과 : 저체중
#
# 이름 : 아나
# 몸무게 : 81
# 키 : 140
# BMI : 41.3265306122449
# 결과 : 과체중
#
# 이름 : 마아
# 몸무게 : 70
# 키 : 174
# BMI : 23.120623596247853
# 결과 : 정상 체중
#
# 이름 : 파카
# 몸무게 : 83
# 키 : 157
# BMI : 33.6727656294373
# 결과 : 과체중
#
# 이름 : 사차
# 몸무게 : 64
# 키 : 180
# BMI : 19.753086419753085
# 결과 : 정상 체중
#
# 이름 : 다파
# 몸무게 : 82
# 키 : 142
# BMI : 40.66653441777425
# 결과 : 과체중
#
# 이름 : 마타
# 몸무게 : 97
# 키 : 150
# BMI : 43.111111111111114
# 결과 : 과체중
#
# 이름 : 사나
# 몸무게 : 51
# 키 : 179
# BMI : 15.917106207671422
# 결과 : 저체중
#
# 이름 : 카아
# 몸무게 : 67
# 키 : 193
# BMI : 17.9870600553035
# 결과 : 저체중
#
# 이름 : 아아
# 몸무게 : 64
# 키 : 179
# BMI : 19.97440779001904
# 결과 : 정상 체중
#
# 이름 : 나차
# 몸무게 : 74
# 키 : 149
# BMI : 33.331831899463985
# 결과 : 과체중
#
# 이름 : 가나
# 몸무게 : 62
# 키 : 155
# BMI : 25.806451612903224
# 결과 : 과체중
#
# 이름 : 라차
# 몸무게 : 45
# 키 : 165
# BMI : 16.528925619834713
# 결과 : 저체중
#
# 이름 : 파다
# 몸무게 : 96
# 키 : 159
# BMI : 37.97318144060757
# 결과 : 과체중
#
# 이름 : 자사
# 몸무게 : 85
# 키 : 177
# BMI : 27.13141179099237
# 결과 : 과체중
#
# 이름 : 가나
# 몸무게 : 79
# 키 : 161
# BMI : 30.477219243084754
# 결과 : 과체중
#
# 이름 : 바차
# 몸무게 : 92
# 키 : 191
# BMI : 25.218606946081522
# 결과 : 과체중
#
# 이름 : 하라
# 몸무게 : 91
# 키 : 170
# BMI : 31.487889273356405
# 결과 : 과체중
#
# 이름 : 다다
# 몸무게 : 47
# 키 : 194
# BMI : 12.488043362737805
# 결과 : 저체중
#
# 이름 : 파차
# 몸무게 : 97
# 키 : 143
# BMI : 47.43508240011737
# 결과 : 과체중
#
# 이름 : 다가
# 몸무게 : 68
# 키 : 176
# BMI : 21.952479338842977
# 결과 : 정상 체중
#
# 이름 : 자라
# 몸무게 : 81
# 키 : 197
# BMI : 20.87144734468809
# 결과 : 정상 체중
#
# 이름 : 자하
# 몸무게 : 43
# 키 : 186
# BMI : 12.429182564458317
# 결과 : 저체중
#
# 이름 : 아자
# 몸무게 : 62
# 키 : 161
# BMI : 23.9188302920412
# 결과 : 정상 체중
#
# 이름 : 타자
# 몸무게 : 41
# 키 : 143
# BMI : 20.049880189740332
# 결과 : 정상 체중
#
# 이름 : 마가
# 몸무게 : 79
# 키 : 160
# BMI : 30.859374999999993
# 결과 : 과체중
#
# 이름 : 라다
# 몸무게 : 51
# 키 : 159
# BMI : 20.17325264032277
# 결과 : 정상 체중
#
# 이름 : 나파
# 몸무게 : 70
# 키 : 182
# BMI : 21.132713440405748
# 결과 : 정상 체중
#
# 이름 : 바자
# 몸무게 : 85
# 키 : 150
# BMI : 37.77777777777778
# 결과 : 과체중
#
# 이름 : 카다
# 몸무게 : 46
# 키 : 145
# BMI : 21.87871581450654
# 결과 : 정상 체중
#
# 이름 : 자카
# 몸무게 : 53
# 키 : 182
# BMI : 16.000483033450067
# 결과 : 저체중
#
# 이름 : 아바
# 몸무게 : 67
# 키 : 189
# BMI : 18.75647378292881
# 결과 : 정상 체중
#
# 이름 : 마다
# 몸무게 : 74
# 키 : 146
# BMI : 34.71570651154063
# 결과 : 과체중
#
# 이름 : 타자
# 몸무게 : 44
# 키 : 160
# BMI : 17.187499999999996
# 결과 : 저체중
#
# 이름 : 타카
# 몸무게 : 98
# 키 : 141
# BMI : 49.29329510587999
# 결과 : 과체중
#
# 이름 : 차타
# 몸무게 : 52
# 키 : 190
# BMI : 14.40443213296399
# 결과 : 저체중
#
# 이름 : 나파
# 몸무게 : 93
# 키 : 151
# BMI : 40.78768475066883
# 결과 : 과체중
#
# 이름 : 파자
# 몸무게 : 86
# 키 : 140
# BMI : 43.87755102040817
# 결과 : 과체중
#
# 이름 : 타라
# 몸무게 : 45
# 키 : 170
# BMI : 15.570934256055365
# 결과 : 저체중
#
# 이름 : 바나
# 몸무게 : 43
# 키 : 173
# BMI : 14.367336028601022
# 결과 : 저체중
#
# 이름 : 파하
# 몸무게 : 42
# 키 : 185
# BMI : 12.271731190650108
# 결과 : 저체중
#
# 이름 : 차라
# 몸무게 : 46
# 키 : 155
# BMI : 19.14672216441207
# 결과 : 정상 체중
#
# 이름 : 바바
# 몸무게 : 57
# 키 : 161
# BMI : 21.98989236526368
# 결과 : 정상 체중
#
# 이름 : 카라
# 몸무게 : 67
# 키 : 146
# BMI : 31.431788328016516
# 결과 : 과체중
#
# 이름 : 차나
# 몸무게 : 64
# 키 : 146
# BMI : 30.024394820791898
# 결과 : 과체중
#
# 이름 : 다바
# 몸무게 : 59
# 키 : 148
# BMI : 26.93571950328707
# 결과 : 과체중
#
# 이름 : 차하
# 몸무게 : 85
# 키 : 158
# BMI : 34.049030604069856
# 결과 : 과체중
#
# 이름 : 파사
# 몸무게 : 87
# 키 : 185
# BMI : 25.420014609203797
# 결과 : 과체중
#
# 이름 : 아파
# 몸무게 : 56
# 키 : 167
# BMI : 20.07960127648894
# 결과 : 정상 체중
#
# 이름 : 가자
# 몸무게 : 59
# 키 : 140
# BMI : 30.102040816326536
# 결과 : 과체중
#
# 이름 : 아마
# 몸무게 : 69
# 키 : 144
# BMI : 33.27546296296296
# 결과 : 과체중
#
# 이름 : 카파
# 몸무게 : 61
# 키 : 199
# BMI : 15.403651422943865
# 결과 : 저체중
#
# 이름 : 라가
# 몸무게 : 41
# 키 : 167
# BMI : 14.701136648857974
# 결과 : 저체중
#
# 이름 : 하가
# 몸무게 : 55
# 키 : 196
# BMI : 14.316951270304042
# 결과 : 저체중
#
# 이름 : 바카
# 몸무게 : 42
# 키 : 171
# BMI : 14.363393864778908
# 결과 : 저체중
#
# 이름 : 다다
# 몸무게 : 57
# 키 : 166
# BMI : 20.685150239512268
# 결과 : 정상 체중
#
# 이름 : 나바
# 몸무게 : 61
# 키 : 141
# BMI : 30.68256123937428
# 결과 : 과체중
#
# 이름 : 사카
# 몸무게 : 59
# 키 : 146
# BMI : 27.67873897541753
# 결과 : 과체중
#
# 이름 : 하하
# 몸무게 : 65
# 키 : 179
# BMI : 20.286507911738084
# 결과 : 정상 체중
#
# 이름 : 가자
# 몸무게 : 58
# 키 : 178
# BMI : 18.30576947355132
# 결과 : 저체중
#
# 이름 : 가마
# 몸무게 : 85
# 키 : 173
# BMI : 28.40054796351365
# 결과 : 과체중
#
# 이름 : 마아
# 몸무게 : 83
# 키 : 146
# BMI : 38.937887033214494
# 결과 : 과체중
#
# 이름 : 다아
# 몸무게 : 99
# 키 : 180
# BMI : 30.555555555555554
# 결과 : 과체중
#
# 이름 : 나라
# 몸무게 : 86
# 키 : 150
# BMI : 38.22222222222222
# 결과 : 과체중
#
# 이름 : 다바
# 몸무게 : 53
# 키 : 190
# BMI : 14.681440443213297
# 결과 : 저체중
#
# 이름 : 하마
# 몸무게 : 59
# 키 : 166
# BMI : 21.410944984758313
# 결과 : 정상 체중
#
# 이름 : 바자
# 몸무게 : 58
# 키 : 182
# BMI : 17.509962564907617
# 결과 : 저체중
#
# 이름 : 사타
# 몸무게 : 70
# 키 : 197
# BMI : 18.037053260841557
# 결과 : 저체중
#
# 이름 : 마다
# 몸무게 : 48
# 키 : 149
# BMI : 21.620647718571234
# 결과 : 정상 체중
#
# 이름 : 마다
# 몸무게 : 59
# 키 : 172
# BMI : 19.94321254732288
# 결과 : 정상 체중
#
# 이름 : 자타
# 몸무게 : 83
# 키 : 146
# BMI : 38.937887033214494
# 결과 : 과체중
#
# 이름 : 마하
# 몸무게 : 89
# 키 : 176
# BMI : 28.731921487603305
# 결과 : 과체중
#
# 이름 : 바마
# 몸무게 : 99
# 키 : 179
# BMI : 30.8979120501857
# 결과 : 과체중
#
# 이름 : 바가
# 몸무게 : 50
# 키 : 179
# BMI : 15.605006085952374
# 결과 : 저체중
#
# 이름 : 차라
# 몸무게 : 83
# 키 : 199
# BMI : 20.959066690235094
# 결과 : 정상 체중
#
# 이름 : 가아
# 몸무게 : 71
# 키 : 149
# BMI : 31.980541417053285
# 결과 : 과체중
#
# 이름 : 카차
# 몸무게 : 50
# 키 : 153
# BMI : 21.35930624973301
# 결과 : 정상 체중
#
# 이름 : 가마
# 몸무게 : 82
# 키 : 173
# BMI : 27.39817568244846
# 결과 : 과체중
#
# 이름 : 카사
# 몸무게 : 45
# 키 : 180
# BMI : 13.888888888888888
# 결과 : 저체중
#
# 이름 : 카마
# 몸무게 : 58
# 키 : 197
# BMI : 14.944986987554433
# 결과 : 저체중
#
# 이름 : 바아
# 몸무게 : 67
# 키 : 146
# BMI : 31.431788328016516
# 결과 : 과체중
#
# 이름 : 파타
# 몸무게 : 62
# 키 : 199
# BMI : 15.65617029872983
# 결과 : 저체중
#
# 이름 : 나라
# 몸무게 : 75
# 키 : 141
# BMI : 37.72446054021428
# 결과 : 과체중
#
# 이름 : 라나
# 몸무게 : 91
# 키 : 199
# BMI : 22.979217696522813
# 결과 : 정상 체중
#
# 이름 : 나하
# 몸무게 : 54
# 키 : 144
# BMI : 26.041666666666668
# 결과 : 과체중
#
# 이름 : 타다
# 몸무게 : 85
# 키 : 181
# BMI : 25.94548395958609
# 결과 : 과체중
#
# 이름 : 하다
# 몸무게 : 66
# 키 : 177
# BMI : 21.06674327300584
# 결과 : 정상 체중
#
# 이름 : 하사
# 몸무게 : 64
# 키 : 146
# BMI : 30.024394820791898
# 결과 : 과체중
#
# 이름 : 사하
# 몸무게 : 76
# 키 : 162
# BMI : 28.959000152415786
# 결과 : 과체중
#
# 이름 : 차가
# 몸무게 : 92
# 키 : 199
# BMI : 23.23173657230878
# 결과 : 정상 체중
#
# 이름 : 사자
# 몸무게 : 65
# 키 : 198
# BMI : 16.579940822365064
# 결과 : 저체중
#
# 이름 : 아아
# 몸무게 : 72
# 키 : 192
# BMI : 19.53125
# 결과 : 정상 체중
#
# 이름 : 타카
# 몸무게 : 74
# 키 : 147
# BMI : 34.24499051321209
# 결과 : 과체중
#
# 이름 : 다사
# 몸무게 : 89
# 키 : 197
# BMI : 22.932824860212836
# 결과 : 정상 체중
#
# 이름 : 사하
# 몸무게 : 59
# 키 : 141
# BMI : 29.676575624968567
# 결과 : 과체중
#
# 이름 : 마차
# 몸무게 : 64
# 키 : 147
# BMI : 29.617289092507754
# 결과 : 과체중
#
# 이름 : 바사
# 몸무게 : 90
# 키 : 164
# BMI : 33.462224866151104
# 결과 : 과체중
#
# 이름 : 라바
# 몸무게 : 98
# 키 : 157
# BMI : 39.75820520102235
# 결과 : 과체중
#
# 이름 : 다카
# 몸무게 : 50
# 키 : 166
# BMI : 18.144868631151112
# 결과 : 저체중
#
# 이름 : 자마
# 몸무게 : 63
# 키 : 142
# BMI : 31.243800833168024
# 결과 : 과체중
#
# 이름 : 아아
# 몸무게 : 82
# 키 : 188
# BMI : 23.20054323223178
# 결과 : 정상 체중
#
# 이름 : 사바
# 몸무게 : 90
# 키 : 166
# BMI : 32.660763536072004
# 결과 : 과체중
#
# 이름 : 가나
# 몸무게 : 63
# 키 : 147
# BMI : 29.15451895043732
# 결과 : 과체중
#
# 이름 : 다하
# 몸무게 : 92
# 키 : 162
# BMI : 35.055631763450684
# 결과 : 과체중
#
# 이름 : 아카
# 몸무게 : 55
# 키 : 176
# BMI : 17.75568181818182
# 결과 : 저체중
#
# 이름 : 타파
# 몸무게 : 43
# 키 : 199
# BMI : 10.858311658796495
# 결과 : 저체중
#
# 이름 : 사사
# 몸무게 : 73
# 키 : 190
# BMI : 20.221606648199447
# 결과 : 정상 체중
#
# 이름 : 아카
# 몸무게 : 83
# 키 : 177
# BMI : 26.493025631204315
# 결과 : 과체중
#
# 이름 : 파카
# 몸무게 : 66
# 키 : 152
# BMI : 28.566481994459835
# 결과 : 과체중
#
# 이름 : 가차
# 몸무게 : 96
# 키 : 173
# BMI : 32.075912994086
# 결과 : 과체중
#
# 이름 : 라하
# 몸무게 : 93
# 키 : 147
# BMI : 43.03762321255033
# 결과 : 과체중
#
# 이름 : 차다
# 몸무게 : 58
# 키 : 140
# BMI : 29.59183673469388
# 결과 : 과체중
#
# 이름 : 사사
# 몸무게 : 56
# 키 : 143
# BMI : 27.385202210377038
# 결과 : 과체중
#
# 이름 : 파사
# 몸무게 : 66
# 키 : 166
# BMI : 23.95122659311947
# 결과 : 정상 체중
#
# 이름 : 다차
# 몸무게 : 77
# 키 : 174
# BMI : 25.43268595587264
# 결과 : 과체중
#
# 이름 : 다바
# 몸무게 : 93
# 키 : 189
# BMI : 26.035105400184765
# 결과 : 과체중
#
# 이름 : 바차
# 몸무게 : 62
# 키 : 142
# BMI : 30.7478674866098
# 결과 : 과체중
#
# 이름 : 사다
# 몸무게 : 80
# 키 : 174
# BMI : 26.42356982428326
# 결과 : 과체중
#
# 이름 : 라하
# 몸무게 : 77
# 키 : 151
# BMI : 33.77044866453226
# 결과 : 과체중
#
# 이름 : 라카
# 몸무게 : 49
# 키 : 147
# BMI : 22.67573696145125
# 결과 : 정상 체중
#
# 이름 : 바파
# 몸무게 : 56
# 키 : 191
# BMI : 15.350456401962665
# 결과 : 저체중
#
# 이름 : 마사
# 몸무게 : 74
# 키 : 167
# BMI : 26.533758829646096
# 결과 : 과체중
#
# 이름 : 마바
# 몸무게 : 73
# 키 : 144
# BMI : 35.204475308641975
# 결과 : 과체중
#
# 이름 : 자자
# 몸무게 : 72
# 키 : 147
# BMI : 33.31945022907122
# 결과 : 과체중
#
# 이름 : 하아
# 몸무게 : 94
# 키 : 150
# BMI : 41.77777777777778
# 결과 : 과체중
#
# 이름 : 아자
# 몸무게 : 45
# 키 : 152
# BMI : 19.47714681440443
# 결과 : 정상 체중
#
# 이름 : 나하
# 몸무게 : 64
# 키 : 141
# BMI : 32.191539660982855
# 결과 : 과체중
#
# 이름 : 마하
# 몸무게 : 57
# 키 : 159
# BMI : 22.54657648036074
# 결과 : 정상 체중
#
# 이름 : 다라
# 몸무게 : 56
# 키 : 184
# BMI : 16.5406427221172
# 결과 : 저체중
#
# 이름 : 자차
# 몸무게 : 80
# 키 : 173
# BMI : 26.729927495071667
# 결과 : 과체중
#
# 이름 : 다차
# 몸무게 : 42
# 키 : 159
# BMI : 16.61326688026581
# 결과 : 저체중
#
# 이름 : 카나
# 몸무게 : 74
# 키 : 148
# BMI : 33.78378378378378
# 결과 : 과체중
#
# 이름 : 마파
# 몸무게 : 56
# 키 : 151
# BMI : 24.560326301478007
# 결과 : 정상 체중
#
# 이름 : 바나
# 몸무게 : 79
# 키 : 171
# BMI : 27.01685988851271
# 결과 : 과체중
#
# 이름 : 타자
# 몸무게 : 85
# 키 : 164
# BMI : 31.603212373587155
# 결과 : 과체중
#
# 이름 : 파가
# 몸무게 : 96
# 키 : 165
# BMI : 35.26170798898072
# 결과 : 과체중
#
# 이름 : 하차
# 몸무게 : 79
# 키 : 147
# BMI : 36.55884122356426
# 결과 : 과체중
#
# 이름 : 나아
# 몸무게 : 93
# 키 : 144
# BMI : 44.84953703703704
# 결과 : 과체중
#
# 이름 : 바아
# 몸무게 : 40
# 키 : 195
# BMI : 10.519395134779751
# 결과 : 저체중
#
# 이름 : 나마
# 몸무게 : 90
# 키 : 173
# BMI : 30.071168431955627
# 결과 : 과체중
#
# 이름 : 라나
# 몸무게 : 42
# 키 : 171
# BMI : 14.363393864778908
# 결과 : 저체중
#
# 이름 : 다파
# 몸무게 : 78
# 키 : 176
# BMI : 25.180785123966942
# 결과 : 과체중
#
# 이름 : 사하
# 몸무게 : 67
# 키 : 153
# BMI : 28.621470374642232
# 결과 : 과체중
#
# 이름 : 차카
# 몸무게 : 59
# 키 : 168
# BMI : 20.904195011337873
# 결과 : 정상 체중
#
# 이름 : 마다
# 몸무게 : 64
# 키 : 142
# BMI : 31.739734179726245
# 결과 : 과체중
#
# 이름 : 바라
# 몸무게 : 43
# 키 : 173
# BMI : 14.367336028601022
# 결과 : 저체중
#
# 이름 : 가가
# 몸무게 : 96
# 키 : 179
# BMI : 29.961611685028558
# 결과 : 과체중
#
# 이름 : 다사
# 몸무게 : 74
# 키 : 176
# BMI : 23.889462809917354
# 결과 : 정상 체중
#
# 이름 : 나자
# 몸무게 : 67
# 키 : 198
# BMI : 17.090092847668604
# 결과 : 저체중
#
# 이름 : 차자
# 몸무게 : 91
# 키 : 182
# BMI : 27.47252747252747
# 결과 : 과체중
#
# 이름 : 가카
# 몸무게 : 54
# 키 : 175
# BMI : 17.632653061224488
# 결과 : 저체중
#
# 이름 : 마가
# 몸무게 : 67
# 키 : 189
# BMI : 18.75647378292881
# 결과 : 정상 체중
#
# 이름 : 아라
# 몸무게 : 80
# 키 : 155
# BMI : 33.29864724245577
# 결과 : 과체중
#
# 이름 : 다마
# 몸무게 : 53
# 키 : 159
# BMI : 20.964360587002094
# 결과 : 정상 체중
#
# 이름 : 파나
# 몸무게 : 62
# 키 : 157
# BMI : 25.153150229218223
# 결과 : 과체중
#
# 이름 : 다가
# 몸무게 : 67
# 키 : 164
# BMI : 24.910767400356935
# 결과 : 정상 체중
#
# 이름 : 카파
# 몸무게 : 98
# 키 : 183
# BMI : 29.26334020126011
# 결과 : 과체중
#
# 이름 : 하라
# 몸무게 : 55
# 키 : 196
# BMI : 14.316951270304042
# 결과 : 저체중
#
# 이름 : 아라
# 몸무게 : 43
# 키 : 175
# BMI : 14.040816326530612
# 결과 : 저체중
#
# 이름 : 타나
# 몸무게 : 43
# 키 : 193
# BMI : 11.543934065344036
# 결과 : 저체중
#
# 이름 : 다아
# 몸무게 : 85
# 키 : 172
# BMI : 28.73174689021093
# 결과 : 과체중
#
# 이름 : 아타
# 몸무게 : 64
# 키 : 158
# BMI : 25.63691716071142
# 결과 : 과체중
#
# 이름 : 차파
# 몸무게 : 71
# 키 : 140
# BMI : 36.22448979591837
# 결과 : 과체중
#
# 이름 : 차사
# 몸무게 : 99
# 키 : 173
# BMI : 33.07828527515119
# 결과 : 과체중
#
# 이름 : 나나
# 몸무게 : 95
# 키 : 188
# BMI : 26.87867813490267
# 결과 : 과체중
#
# 이름 : 차다
# 몸무게 : 59
# 키 : 164
# BMI : 21.936347412254616
# 결과 : 정상 체중
#
# 이름 : 자카
# 몸무게 : 63
# 키 : 155
# BMI : 26.22268470343392
# 결과 : 과체중
#
# 이름 : 바가
# 몸무게 : 91
# 키 : 170
# BMI : 31.487889273356405
# 결과 : 과체중
#
# 이름 : 라하
# 몸무게 : 55
# 키 : 185
# BMI : 16.070124178232284
# 결과 : 저체중
#
# 이름 : 하차
# 몸무게 : 82
# 키 : 163
# BMI : 30.863035868869737
# 결과 : 과체중
#
# 이름 : 사아
# 몸무게 : 61
# 키 : 163
# BMI : 22.95908765854944
# 결과 : 정상 체중
#
# 이름 : 나나
# 몸무게 : 66
# 키 : 174
# BMI : 21.79944510503369
# 결과 : 정상 체중
#
# 이름 : 사사
# 몸무게 : 63
# 키 : 140
# BMI : 32.142857142857146
# 결과 : 과체중
#
# 이름 : 사카
# 몸무게 : 41
# 키 : 181
# BMI : 12.514880498153293
# 결과 : 저체중
#
# 이름 : 자사
# 몸무게 : 88
# 키 : 146
# BMI : 41.28354287858886
# 결과 : 과체중
#
# 이름 : 마아
# 몸무게 : 77
# 키 : 183
# BMI : 22.99262444384723
# 결과 : 정상 체중
#
# 이름 : 하자
# 몸무게 : 53
# 키 : 150
# BMI : 23.555555555555557
# 결과 : 정상 체중
#
# 이름 : 바라
# 몸무게 : 75
# 키 : 186
# BMI : 21.678806798473808
# 결과 : 정상 체중
#
# 이름 : 파라
# 몸무게 : 60
# 키 : 148
# BMI : 27.39225712198685
# 결과 : 과체중
#
# 이름 : 하차
# 몸무게 : 40
# 키 : 184
# BMI : 11.814744801512287
# 결과 : 저체중
#
# 이름 : 아사
# 몸무게 : 80
# 키 : 178
# BMI : 25.24933720489837
# 결과 : 과체중
#
# 이름 : 바사
# 몸무게 : 55
# 키 : 182
# BMI : 16.604274846033086
# 결과 : 저체중
#
# 이름 : 가파
# 몸무게 : 82
# 키 : 143
# BMI : 40.099760379480664
# 결과 : 과체중
#
# 이름 : 차가
# 몸무게 : 72
# 키 : 199
# BMI : 18.18135905658948
# 결과 : 저체중
#
# 이름 : 아차
# 몸무게 : 43
# 키 : 185
# BMI : 12.563915266617968
# 결과 : 저체중
#
# 이름 : 사라
# 몸무게 : 49
# 키 : 172
# BMI : 16.563007030827475
# 결과 : 저체중
#
# 이름 : 하바
# 몸무게 : 82
# 키 : 176
# BMI : 26.47210743801653
# 결과 : 과체중
#
# 이름 : 파바
# 몸무게 : 79
# 키 : 154
# BMI : 33.310844999156686
# 결과 : 과체중
#
# 이름 : 차나
# 몸무게 : 41
# 키 : 143
# BMI : 20.049880189740332
# 결과 : 정상 체중
#
# 이름 : 파가
# 몸무게 : 67
# 키 : 149
# BMI : 30.178820773839018
# 결과 : 과체중
#
# 이름 : 카카
# 몸무게 : 55
# 키 : 140
# BMI : 28.061224489795922
# 결과 : 과체중
#
# 이름 : 파사
# 몸무게 : 83
# 키 : 176
# BMI : 26.794938016528928
# 결과 : 과체중
#
# 이름 : 자사
# 몸무게 : 68
# 키 : 180
# BMI : 20.98765432098765
# 결과 : 정상 체중
#
# 이름 : 나카
# 몸무게 : 93
# 키 : 140
# BMI : 47.44897959183674
# 결과 : 과체중
#
# 이름 : 차하
# 몸무게 : 73
# 키 : 140
# BMI : 37.24489795918368
# 결과 : 과체중
#
# 이름 : 카라
# 몸무게 : 62
# 키 : 155
# BMI : 25.806451612903224
# 결과 : 과체중
#
# 이름 : 파카
# 몸무게 : 58
# 키 : 155
# BMI : 24.141519250780433
# 결과 : 정상 체중
#
# 이름 : 라나
# 몸무게 : 60
# 키 : 188
# BMI : 16.976007243096426
# 결과 : 저체중
#
# 이름 : 차카
# 몸무게 : 60
# 키 : 197
# BMI : 15.46033136643562
# 결과 : 저체중
#
# 이름 : 바사
# 몸무게 : 66
# 키 : 181
# BMI : 20.1459051921492
# 결과 : 정상 체중
#
# 이름 : 아바
# 몸무게 : 98
# 키 : 154
# BMI : 41.32231404958678
# 결과 : 과체중
#
# 이름 : 아바
# 몸무게 : 57
# 키 : 141
# BMI : 28.67059001056285
# 결과 : 과체중
#
# 이름 : 아차
# 몸무게 : 52
# 키 : 184
# BMI : 15.359168241965973
# 결과 : 저체중
#
# 이름 : 하파
# 몸무게 : 89
# 키 : 172
# BMI : 30.08382909680909
# 결과 : 과체중
#
# 이름 : 자마
# 몸무게 : 68
# 키 : 157
# BMI : 27.587326057852245
# 결과 : 과체중
#
# 이름 : 파파
# 몸무게 : 57
# 키 : 140
# BMI : 29.081632653061227
# 결과 : 과체중
#
# 이름 : 자자
# 몸무게 : 66
# 키 : 179
# BMI : 20.598608033457133
# 결과 : 정상 체중
#
# 이름 : 나파
# 몸무게 : 62
# 키 : 159
# BMI : 24.524346347059055
# 결과 : 정상 체중
#
# 이름 : 자바
# 몸무게 : 95
# 키 : 198
# BMI : 24.232221201918172
# 결과 : 정상 체중
#
# 이름 : 아자
# 몸무게 : 60
# 키 : 179
# BMI : 18.726007303142847
# 결과 : 정상 체중
#
# 이름 : 가마
# 몸무게 : 59
# 키 : 166
# BMI : 21.410944984758313
# 결과 : 정상 체중
#
# 이름 : 라바
# 몸무게 : 93
# 키 : 165
# BMI : 34.159779614325075
# 결과 : 과체중
#
# 이름 : 마라
# 몸무게 : 68
# 키 : 194
# BMI : 18.067807418429165
# 결과 : 저체중
#
# 이름 : 파하
# 몸무게 : 86
# 키 : 157
# BMI : 34.889853543754306
# 결과 : 과체중
#
# 이름 : 라라
# 몸무게 : 68
# 키 : 198
# BMI : 17.345168860320378
# 결과 : 저체중
#
# 이름 : 하가
# 몸무게 : 72
# 키 : 191
# BMI : 19.736301088237713
# 결과 : 정상 체중
#
# 이름 : 아아
# 몸무게 : 89
# 키 : 180
# BMI : 27.469135802469133
# 결과 : 과체중
#
# 이름 : 가차
# 몸무게 : 88
# 키 : 166
# BMI : 31.934968790825955
# 결과 : 과체중
#
# 이름 : 하다
# 몸무게 : 97
# 키 : 186
# BMI : 28.037923459359458
# 결과 : 과체중
#
# 이름 : 하차
# 몸무게 : 82
# 키 : 141
# BMI : 41.24541019063428
# 결과 : 과체중
#
# 이름 : 타아
# 몸무게 : 82
# 키 : 184
# BMI : 24.22022684310019
# 결과 : 정상 체중
#
# 이름 : 파다
# 몸무게 : 64
# 키 : 178
# BMI : 20.199469763918696
# 결과 : 정상 체중
#
# 이름 : 타타
# 몸무게 : 43
# 키 : 188
# BMI : 12.166138524219104
# 결과 : 저체중
#
# 이름 : 하하
# 몸무게 : 63
# 키 : 168
# BMI : 22.321428571428577
# 결과 : 정상 체중
#
# 이름 : 타가
# 몸무게 : 59
# 키 : 159
# BMI : 23.337684427040067
# 결과 : 정상 체중
#
# 이름 : 나카
# 몸무게 : 85
# 키 : 189
# BMI : 23.79552644102909
# 결과 : 정상 체중
#
# 이름 : 라카
# 몸무게 : 99
# 키 : 198
# BMI : 25.252525252525253
# 결과 : 과체중
#
# 이름 : 나타
# 몸무게 : 56
# 키 : 154
# BMI : 23.61275088547816
# 결과 : 정상 체중
#
# 이름 : 차카
# 몸무게 : 74
# 키 : 151
# BMI : 32.45471689838165
# 결과 : 과체중
#
# 이름 : 라나
# 몸무게 : 86
# 키 : 177
# BMI : 27.450604870886398
# 결과 : 과체중
#
# 이름 : 사가
# 몸무게 : 85
# 키 : 171
# BMI : 29.06877329776684
# 결과 : 과체중
#
# 이름 : 타라
# 몸무게 : 77
# 키 : 187
# BMI : 22.019502988361115
# 결과 : 정상 체중
#
# 이름 : 다하
# 몸무게 : 67
# 키 : 170
# BMI : 23.18339100346021
# 결과 : 정상 체중
#
# 이름 : 가다
# 몸무게 : 55
# 키 : 171
# BMI : 18.80920625149619
# 결과 : 정상 체중
#
# 이름 : 사다
# 몸무게 : 41
# 키 : 141
# BMI : 20.62270509531714
# 결과 : 정상 체중
#
# 이름 : 파사
# 몸무게 : 72
# 키 : 197
# BMI : 18.552397639722745
# 결과 : 정상 체중
#
# 이름 : 파가
# 몸무게 : 47
# 키 : 148
# BMI : 21.4572680788897
# 결과 : 정상 체중
#
# 이름 : 바사
# 몸무게 : 87
# 키 : 190
# BMI : 24.099722991689752
# 결과 : 정상 체중
#
# 이름 : 타사
# 몸무게 : 51
# 키 : 143
# BMI : 24.940094870164803
# 결과 : 정상 체중
#
# 이름 : 아가
# 몸무게 : 80
# 키 : 188
# BMI : 22.634676324128566
# 결과 : 정상 체중
#
# 이름 : 자자
# 몸무게 : 49
# 키 : 190
# BMI : 13.573407202216067
# 결과 : 저체중
#
# 이름 : 가마
# 몸무게 : 50
# 키 : 163
# BMI : 18.818924310286427
# 결과 : 정상 체중
#
# 이름 : 바카
# 몸무게 : 85
# 키 : 194
# BMI : 22.584759273036454
# 결과 : 정상 체중
#
# 이름 : 파나
# 몸무게 : 84
# 키 : 188
# BMI : 23.766410140334994
# 결과 : 정상 체중
#
# 이름 : 라타
# 몸무게 : 68
# 키 : 183
# BMI : 20.305174833527424
# 결과 : 정상 체중
#
# 이름 : 나타
# 몸무게 : 67
# 키 : 169
# BMI : 23.458562375266975
# 결과 : 정상 체중
#
# 이름 : 마다
# 몸무게 : 70
# 키 : 197
# BMI : 18.037053260841557
# 결과 : 저체중
#
# 이름 : 차카
# 몸무게 : 64
# 키 : 163
# BMI : 24.088223117166624
# 결과 : 정상 체중
#
# 이름 : 라다
# 몸무게 : 56
# 키 : 150
# BMI : 24.88888888888889
# 결과 : 정상 체중
#
# 이름 : 카사
# 몸무게 : 58
# 키 : 141
# BMI : 29.17358281776571
# 결과 : 과체중
#
# 이름 : 카가
# 몸무게 : 75
# 키 : 195
# BMI : 19.723865877712033
# 결과 : 정상 체중
#
# 이름 : 하차
# 몸무게 : 59
# 키 : 148
# BMI : 26.93571950328707
# 결과 : 과체중
#
# 이름 : 라카
# 몸무게 : 85
# 키 : 192
# BMI : 23.057725694444446
# 결과 : 정상 체중
#
# 이름 : 마타
# 몸무게 : 86
# 키 : 166
# BMI : 31.20917404557991
# 결과 : 과체중
#
# 이름 : 바사
# 몸무게 : 91
# 키 : 199
# BMI : 22.979217696522813
# 결과 : 정상 체중
#
# 이름 : 바나
# 몸무게 : 73
# 키 : 150
# BMI : 32.44444444444444
# 결과 : 과체중
#
# 이름 : 마다
# 몸무게 : 62
# 키 : 191
# BMI : 16.995148159315807
# 결과 : 저체중
#
# 이름 : 가카
# 몸무게 : 77
# 키 : 197
# BMI : 19.840758586925713
# 결과 : 정상 체중
#
# 이름 : 카마
# 몸무게 : 43
# 키 : 158
# BMI : 17.224803717352987
# 결과 : 저체중
#
# 이름 : 파라
# 몸무게 : 65
# 키 : 168
# BMI : 23.030045351473927
# 결과 : 정상 체중
#
# 이름 : 타사
# 몸무게 : 80
# 키 : 172
# BMI : 27.041644131963228
# 결과 : 과체중
#
# 이름 : 차마
# 몸무게 : 65
# 키 : 149
# BMI : 29.27796045223188
# 결과 : 과체중
#
# 이름 : 사나
# 몸무게 : 68
# 키 : 186
# BMI : 19.65545149728292
# 결과 : 정상 체중
#
# 이름 : 바다
# 몸무게 : 81
# 키 : 160
# BMI : 31.640624999999993
# 결과 : 과체중
#
# 이름 : 가하
# 몸무게 : 74
# 키 : 180
# BMI : 22.839506172839506
# 결과 : 정상 체중
#
# 이름 : 다바
# 몸무게 : 73
# 키 : 149
# BMI : 32.88140173866042
# 결과 : 과체중
#
# 이름 : 타바
# 몸무게 : 50
# 키 : 175
# BMI : 16.3265306122449
# 결과 : 저체중
#
# 이름 : 나사
# 몸무게 : 55
# 키 : 193
# BMI : 14.765497060323767
# 결과 : 저체중
#
# 이름 : 마다
# 몸무게 : 57
# 키 : 187
# BMI : 16.300151562812776
# 결과 : 저체중
#
# 이름 : 타사
# 몸무게 : 61
# 키 : 147
# BMI : 28.228978666296452
# 결과 : 과체중
#
# 이름 : 라카
# 몸무게 : 70
# 키 : 177
# BMI : 22.34351559258195
# 결과 : 정상 체중
#
# 이름 : 차나
# 몸무게 : 76
# 키 : 140
# BMI : 38.77551020408164
# 결과 : 과체중
#
# 이름 : 다나
# 몸무게 : 55
# 키 : 149
# BMI : 24.77365884419621
# 결과 : 정상 체중
#
# 이름 : 파차
# 몸무게 : 83
# 키 : 199
# BMI : 20.959066690235094
# 결과 : 정상 체중
#
# 이름 : 아차
# 몸무게 : 76
# 키 : 180
# BMI : 23.456790123456788
# 결과 : 정상 체중
#
# 이름 : 사아
# 몸무게 : 80
# 키 : 194
# BMI : 21.25624402168137
# 결과 : 정상 체중
#
# 이름 : 자바
# 몸무게 : 97
# 키 : 169
# BMI : 33.96239627464025
# 결과 : 과체중
#
# 이름 : 다파
# 몸무게 : 99
# 키 : 175
# BMI : 32.326530612244895
# 결과 : 과체중
#
# 이름 : 아다
# 몸무게 : 41
# 키 : 187
# BMI : 11.724670422374102
# 결과 : 저체중
#
# 이름 : 타파
# 몸무게 : 78
# 키 : 158
# BMI : 31.244992789617044
# 결과 : 과체중
#
# 이름 : 자라
# 몸무게 : 49
# 키 : 166
# BMI : 17.78197125852809
# 결과 : 저체중
#
# 이름 : 파카
# 몸무게 : 94
# 키 : 175
# BMI : 30.693877551020407
# 결과 : 과체중
#
# 이름 : 마파
# 몸무게 : 54
# 키 : 166
# BMI : 19.5964581216432
# 결과 : 정상 체중
#
# 이름 : 파가
# 몸무게 : 95
# 키 : 189
# BMI : 26.595000139973685
# 결과 : 과체중
#
# 이름 : 라바
# 몸무게 : 41
# 키 : 155
# BMI : 17.065556711758582
# 결과 : 저체중
#
# 이름 : 파카
# 몸무게 : 67
# 키 : 167
# BMI : 24.023808670084982
# 결과 : 정상 체중
#
# 이름 : 바라
# 몸무게 : 70
# 키 : 196
# BMI : 18.221574344023324
# 결과 : 저체중
#
# 이름 : 라자
# 몸무게 : 97
# 키 : 196
# BMI : 25.249895876718035
# 결과 : 과체중
#
# 이름 : 파라
# 몸무게 : 62
# 키 : 145
# BMI : 29.48870392390012
# 결과 : 과체중
#
# 이름 : 차하
# 몸무게 : 50
# 키 : 157
# BMI : 20.28479857195018
# 결과 : 정상 체중
#
# 이름 : 자타
# 몸무게 : 72
# 키 : 198
# BMI : 18.36547291092746
# 결과 : 저체중
#
# 이름 : 나차
# 몸무게 : 98
# 키 : 184
# BMI : 28.946124763705104
# 결과 : 과체중
#
# 이름 : 다아
# 몸무게 : 66
# 키 : 187
# BMI : 18.873859704309528
# 결과 : 정상 체중
#
# 이름 : 타바
# 몸무게 : 72
# 키 : 197
# BMI : 18.552397639722745
# 결과 : 정상 체중
#
# 이름 : 사다
# 몸무게 : 94
# 키 : 193
# BMI : 25.235576794007894
# 결과 : 과체중
#
# 이름 : 차라
# 몸무게 : 50
# 키 : 189
# BMI : 13.997368494722993
# 결과 : 저체중
#
# 이름 : 파아
# 몸무게 : 68
# 키 : 179
# BMI : 21.22280827689523
# 결과 : 정상 체중
#
# 이름 : 라카
# 몸무게 : 82
# 키 : 185
# BMI : 23.959094229364496
# 결과 : 정상 체중
#
# 이름 : 파차
# 몸무게 : 51
# 키 : 151
# BMI : 22.367440024560327
# 결과 : 정상 체중
#
# 이름 : 카가
# 몸무게 : 80
# 키 : 175
# BMI : 26.122448979591837
# 결과 : 과체중
#
# 이름 : 카자
# 몸무게 : 86
# 키 : 197
# BMI : 22.159808291891057
# 결과 : 정상 체중
#
# 이름 : 라가
# 몸무게 : 96
# 키 : 161
# BMI : 37.03560819412831
# 결과 : 과체중
#
# 이름 : 파가
# 몸무게 : 76
# 키 : 143
# BMI : 37.16563157122598
# 결과 : 과체중
#
# 이름 : 마가
# 몸무게 : 63
# 키 : 182
# BMI : 19.01944209636517
# 결과 : 정상 체중
#
# 이름 : 나가
# 몸무게 : 88
# 키 : 187
# BMI : 25.165146272412706
# 결과 : 과체중
#
# 이름 : 나타
# 몸무게 : 75
# 키 : 174
# BMI : 24.772096710265558
# 결과 : 정상 체중
#
# 이름 : 마파
# 몸무게 : 63
# 키 : 196
# BMI : 16.399416909620992
# 결과 : 저체중
#
# 이름 : 가아
# 몸무게 : 94
# 키 : 175
# BMI : 30.693877551020407
# 결과 : 과체중
#
# 이름 : 자마
# 몸무게 : 69
# 키 : 175
# BMI : 22.53061224489796
# 결과 : 정상 체중
#
# 이름 : 아다
# 몸무게 : 88
# 키 : 149
# BMI : 39.637854150713935
# 결과 : 과체중
#
# 이름 : 나바
# 몸무게 : 45
# 키 : 197
# BMI : 11.595248524826715
# 결과 : 저체중
#
# 이름 : 하사
# 몸무게 : 58
# 키 : 166
# BMI : 21.04804761213529
# 결과 : 정상 체중
#
# 이름 : 자타
# 몸무게 : 51
# 키 : 146
# BMI : 23.925689622818542
# 결과 : 정상 체중
#
# 이름 : 바마
# 몸무게 : 98
# 키 : 193
# BMI : 26.309431125667803
# 결과 : 과체중
#
# 이름 : 라라
# 몸무게 : 42
# 키 : 168
# BMI : 14.880952380952383
# 결과 : 저체중
#
# 이름 : 라자
# 몸무게 : 67
# 키 : 181
# BMI : 20.45114617990904
# 결과 : 정상 체중
#
# 이름 : 다라
# 몸무게 : 75
# 키 : 157
# BMI : 30.427197857925268
# 결과 : 과체중
#
# 이름 : 가하
# 몸무게 : 53
# 키 : 194
# BMI : 14.082261664363907
# 결과 : 저체중
#
# 이름 : 라사
# 몸무게 : 91
# 키 : 186
# BMI : 26.303618915481554
# 결과 : 과체중
#
# 이름 : 아아
# 몸무게 : 44
# 키 : 159
# BMI : 17.404374826945133
# 결과 : 저체중
#
# 이름 : 파카
# 몸무게 : 75
# 키 : 154
# BMI : 31.624219935908247
# 결과 : 과체중
#
# 이름 : 자바
# 몸무게 : 84
# 키 : 171
# BMI : 28.726787729557817
# 결과 : 과체중
#
# 이름 : 하자
# 몸무게 : 71
# 키 : 182
# BMI : 21.434609346697258
# 결과 : 정상 체중
#
# 이름 : 나아
# 몸무게 : 89
# 키 : 148
# BMI : 40.6318480642805
# 결과 : 과체중
#
# 이름 : 타마
# 몸무게 : 87
# 키 : 152
# BMI : 37.655817174515235
# 결과 : 과체중
#
# 이름 : 카하
# 몸무게 : 60
# 키 : 164
# BMI : 22.308149910767405
# 결과 : 정상 체중
#
# 이름 : 마타
# 몸무게 : 64
# 키 : 195
# BMI : 16.8310322156476
# 결과 : 저체중
#
# 이름 : 차라
# 몸무게 : 47
# 키 : 182
# BMI : 14.189107595701001
# 결과 : 저체중
#
# 이름 : 사사
# 몸무게 : 47
# 키 : 187
# BMI : 13.440475850038604
# 결과 : 저체중
#
# 이름 : 파마
# 몸무게 : 71
# 키 : 153
# BMI : 30.33021487462087
# 결과 : 과체중
#
# 이름 : 파가
# 몸무게 : 82
# 키 : 190
# BMI : 22.714681440443215
# 결과 : 정상 체중
#
# 이름 : 다카
# 몸무게 : 69
# 키 : 181
# BMI : 21.06162815542871
# 결과 : 정상 체중
#
# 이름 : 가파
# 몸무게 : 75
# 키 : 184
# BMI : 22.152646502835537
# 결과 : 정상 체중
#
# 이름 : 가파
# 몸무게 : 46
# 키 : 160
# BMI : 17.968749999999996
# 결과 : 저체중
#
# 이름 : 자다
# 몸무게 : 41
# 키 : 158
# BMI : 16.423650056080753
# 결과 : 저체중
#
# 이름 : 나파
# 몸무게 : 71
# 키 : 182
# BMI : 21.434609346697258
# 결과 : 정상 체중
#
# 이름 : 다나
# 몸무게 : 79
# 키 : 177
# BMI : 25.2162533116282
# 결과 : 과체중
#
# 이름 : 자다
# 몸무게 : 74
# 키 : 185
# BMI : 21.62162162162162
# 결과 : 정상 체중
#
# 이름 : 파사
# 몸무게 : 81
# 키 : 182
# BMI : 24.453568409612362
# 결과 : 정상 체중
#
# 이름 : 아나
# 몸무게 : 99
# 키 : 154
# BMI : 41.74397031539889
# 결과 : 과체중
#
# 이름 : 차하
# 몸무게 : 63
# 키 : 198
# BMI : 16.069788797061523
# 결과 : 저체중
#
# 이름 : 바차
# 몸무게 : 79
# 키 : 169
# BMI : 27.660095935016283
# 결과 : 과체중
#
# 이름 : 가아
# 몸무게 : 49
# 키 : 190
# BMI : 13.573407202216067
# 결과 : 저체중
#
# 이름 : 나마
# 몸무게 : 91
# 키 : 146
# BMI : 42.69093638581348
# 결과 : 과체중
#
# 이름 : 가마
# 몸무게 : 89
# 키 : 185
# BMI : 26.004382761139514
# 결과 : 과체중
#
# 이름 : 파차
# 몸무게 : 73
# 키 : 185
# BMI : 21.32943754565376
# 결과 : 정상 체중
#
# 이름 : 차차
# 몸무게 : 91
# 키 : 199
# BMI : 22.979217696522813
# 결과 : 정상 체중
#
# 이름 : 바파
# 몸무게 : 85
# 키 : 172
# BMI : 28.73174689021093
# 결과 : 과체중
#
# 이름 : 자차
# 몸무게 : 62
# 키 : 177
# BMI : 19.789970953429727
# 결과 : 정상 체중
#
# 이름 : 하타
# 몸무게 : 40
# 키 : 197
# BMI : 10.306887577623748
# 결과 : 저체중
#
# 이름 : 다자
# 몸무게 : 51
# 키 : 183
# BMI : 15.228881125145568
# 결과 : 저체중
#
# 이름 : 바하
# 몸무게 : 95
# 키 : 194
# BMI : 25.241789775746625
# 결과 : 과체중
#
# 이름 : 가바
# 몸무게 : 64
# 키 : 168
# BMI : 22.67573696145125
# 결과 : 정상 체중
#
# 이름 : 나가
# 몸무게 : 51
# 키 : 154
# BMI : 21.504469556417607
# 결과 : 정상 체중
#
# 이름 : 자다
# 몸무게 : 52
# 키 : 140
# BMI : 26.530612244897963
# 결과 : 과체중
#
# 이름 : 나라
# 몸무게 : 80
# 키 : 141
# BMI : 40.239424576228565
# 결과 : 과체중
#
# 이름 : 다다
# 몸무게 : 94
# 키 : 173
# BMI : 31.40766480670921
# 결과 : 과체중
#
# 이름 : 다가
# 몸무게 : 82
# 키 : 141
# BMI : 41.24541019063428
# 결과 : 과체중
#
# 이름 : 가차
# 몸무게 : 66
# 키 : 159
# BMI : 26.106562240417702
# 결과 : 과체중
#
# 이름 : 사사
# 몸무게 : 91
# 키 : 148
# BMI : 41.54492330168006
# 결과 : 과체중
#
# 이름 : 하아
# 몸무게 : 93
# 키 : 185
# BMI : 27.173119065010955
# 결과 : 과체중
#
# 이름 : 사차
# 몸무게 : 94
# 키 : 195
# BMI : 24.720578566732414
# 결과 : 정상 체중
#
# 이름 : 자아
# 몸무게 : 99
# 키 : 194
# BMI : 26.304601976830696
# 결과 : 과체중
#
# 이름 : 파타
# 몸무게 : 54
# 키 : 165
# BMI : 19.834710743801654
# 결과 : 정상 체중
#
# 이름 : 카나
# 몸무게 : 48
# 키 : 158
# BMI : 19.227687870533565
# 결과 : 정상 체중
#
# 이름 : 가카
# 몸무게 : 66
# 키 : 184
# BMI : 19.494328922495274
# 결과 : 정상 체중
#
# 이름 : 라다
# 몸무게 : 65
# 키 : 183
# BMI : 19.409358296754156
# 결과 : 정상 체중
#
# 이름 : 파아
# 몸무게 : 86
# 키 : 152
# BMI : 37.22299168975069
# 결과 : 과체중
#
# 이름 : 가바
# 몸무게 : 91
# 키 : 184
# BMI : 26.878544423440452
# 결과 : 과체중
#
# 이름 : 아나
# 몸무게 : 62
# 키 : 177
# BMI : 19.789970953429727
# 결과 : 정상 체중
#
# 이름 : 차바
# 몸무게 : 48
# 키 : 151
# BMI : 21.051708258409718
# 결과 : 정상 체중
#
# 이름 : 사자
# 몸무게 : 74
# 키 : 182
# BMI : 22.34029706557179
# 결과 : 정상 체중
#
# 이름 : 자타
# 몸무게 : 50
# 키 : 180
# BMI : 15.432098765432098
# 결과 : 저체중
#
# 이름 : 나하
# 몸무게 : 56
# 키 : 175
# BMI : 18.285714285714285
# 결과 : 저체중
#
# 이름 : 바사
# 몸무게 : 56
# 키 : 155
# BMI : 23.309053069719038
# 결과 : 정상 체중
#
# 이름 : 마가
# 몸무게 : 60
# 키 : 193
# BMI : 16.107814974898655
# 결과 : 저체중
#
# 이름 : 카라
# 몸무게 : 99
# 키 : 159
# BMI : 39.15984336062655
# 결과 : 과체중
#
# 이름 : 차카
# 몸무게 : 74
# 키 : 144
# BMI : 35.68672839506173
# 결과 : 과체중
#
# 이름 : 나마
# 몸무게 : 43
# 키 : 145
# BMI : 20.451843043995243
# 결과 : 정상 체중
#
# 이름 : 자카
# 몸무게 : 92
# 키 : 157
# BMI : 37.32402937238833
# 결과 : 과체중
#
# 이름 : 카아
# 몸무게 : 95
# 키 : 142
# BMI : 47.113667923031144
# 결과 : 과체중
#
# 이름 : 타다
# 몸무게 : 51
# 키 : 181
# BMI : 15.567290375751655
# 결과 : 저체중
#
# 이름 : 바타
# 몸무게 : 67
# 키 : 155
# BMI : 27.887617065556707
# 결과 : 과체중
#
# 이름 : 아차
# 몸무게 : 80
# 키 : 159
# BMI : 31.644317867172973
# 결과 : 과체중
#
# 이름 : 자마
# 몸무게 : 52
# 키 : 145
# BMI : 24.732461355529132
# 결과 : 정상 체중
#
# 이름 : 마차
# 몸무게 : 75
# 키 : 183
# BMI : 22.395413419331717
# 결과 : 정상 체중
#
# 이름 : 사나
# 몸무게 : 50
# 키 : 152
# BMI : 21.641274238227147
# 결과 : 정상 체중
#
# 이름 : 타바
# 몸무게 : 44
# 키 : 144
# BMI : 21.219135802469136
# 결과 : 정상 체중
#
# 이름 : 마카
# 몸무게 : 64
# 키 : 195
# BMI : 16.8310322156476
# 결과 : 저체중
#
# 이름 : 나마
# 몸무게 : 57
# 키 : 198
# BMI : 14.539332721150904
# 결과 : 저체중
#
# 이름 : 바카
# 몸무게 : 95
# 키 : 171
# BMI : 32.488628979857054
# 결과 : 과체중
#
# 이름 : 나파
# 몸무게 : 61
# 키 : 164
# BMI : 22.679952409280194
# 결과 : 정상 체중
#
# 이름 : 파다
# 몸무게 : 44
# 키 : 145
# BMI : 20.92746730083234
# 결과 : 정상 체중
#
# 이름 : 타가
# 몸무게 : 42
# 키 : 149
# BMI : 18.91806675374983
# 결과 : 정상 체중
#
# 이름 : 바카
# 몸무게 : 96
# 키 : 173
# BMI : 32.075912994086
# 결과 : 과체중
#
# 이름 : 아하
# 몸무게 : 52
# 키 : 171
# BMI : 17.783249546869126
# 결과 : 저체중
#
# 이름 : 타하
# 몸무게 : 85
# 키 : 195
# BMI : 22.353714661406972
# 결과 : 정상 체중
#
# 이름 : 파사
# 몸무게 : 94
# 키 : 160
# BMI : 36.71874999999999
# 결과 : 과체중
#
# 이름 : 사자
# 몸무게 : 59
# 키 : 166
# BMI : 21.410944984758313
# 결과 : 정상 체중
#
# 이름 : 차파
# 몸무게 : 79
# 키 : 192
# BMI : 21.43012152777778
# 결과 : 정상 체중
#
# 이름 : 바마
# 몸무게 : 81
# 키 : 190
# BMI : 22.437673130193907
# 결과 : 정상 체중
#
# 이름 : 라카
# 몸무게 : 52
# 키 : 164
# BMI : 19.333729922665082
# 결과 : 정상 체중
#
# 이름 : 마라
# 몸무게 : 63
# 키 : 152
# BMI : 27.268005540166204
# 결과 : 과체중
#
# 이름 : 사자
# 몸무게 : 91
# 키 : 172
# BMI : 30.75987020010817
# 결과 : 과체중
#
# 이름 : 아라
# 몸무게 : 84
# 키 : 151
# BMI : 36.84048945221701
# 결과 : 과체중
#
# 이름 : 나파
# 몸무게 : 41
# 키 : 149
# BMI : 18.467636592946263
# 결과 : 저체중
#
# 이름 : 아타
# 몸무게 : 49
# 키 : 191
# BMI : 13.431649351717333
# 결과 : 저체중
#
# 이름 : 마하
# 몸무게 : 87
# 키 : 149
# BMI : 39.187423989910364
# 결과 : 과체중
#
# 이름 : 하하
# 몸무게 : 75
# 키 : 165
# BMI : 27.548209366391188
# 결과 : 과체중
#
# 이름 : 차바
# 몸무게 : 47
# 키 : 156
# BMI : 19.312952005259696
# 결과 : 정상 체중
#
# 이름 : 가바
# 몸무게 : 46
# 키 : 176
# BMI : 14.850206611570249
# 결과 : 저체중
#
# 이름 : 파차
# 몸무게 : 94
# 키 : 150
# BMI : 41.77777777777778
# 결과 : 과체중
#
# 이름 : 나자
# 몸무게 : 92
# 키 : 153
# BMI : 39.30112349950873
# 결과 : 과체중
#
# 이름 : 가라
# 몸무게 : 73
# 키 : 192
# BMI : 19.80251736111111
# 결과 : 정상 체중
#
# 이름 : 사라
# 몸무게 : 51
# 키 : 199
# BMI : 12.878462665084214
# 결과 : 저체중
#
# 이름 : 파차
# 몸무게 : 71
# 키 : 169
# BMI : 24.859073561850078
# 결과 : 정상 체중
#
# 이름 : 파다
# 몸무게 : 55
# 키 : 157
# BMI : 22.313278429145196
# 결과 : 정상 체중
#
# 이름 : 다타
# 몸무게 : 94
# 키 : 195
# BMI : 24.720578566732414
# 결과 : 정상 체중
#
# 이름 : 다파
# 몸무게 : 72
# 키 : 152
# BMI : 31.16343490304709
# 결과 : 과체중
#
# 이름 : 아바
# 몸무게 : 80
# 키 : 146
# BMI : 37.53049352598987
# 결과 : 과체중
#
# 이름 : 바사
# 몸무게 : 74
# 키 : 173
# BMI : 24.725182932941294
# 결과 : 정상 체중
#
# 이름 : 하파
# 몸무게 : 79
# 키 : 197
# BMI : 20.3561029658069
# 결과 : 정상 체중
#
# 이름 : 카하
# 몸무게 : 94
# 키 : 183
# BMI : 28.068918152229088
# 결과 : 과체중
#
# 이름 : 자파
# 몸무게 : 90
# 키 : 171
# BMI : 30.778701138811947
# 결과 : 과체중
#
# 이름 : 바나
# 몸무게 : 50
# 키 : 176
# BMI : 16.141528925619834
# 결과 : 저체중
#
# 이름 : 가자
# 몸무게 : 77
# 키 : 172
# BMI : 26.027582477014604
# 결과 : 과체중
#
# 이름 : 하카
# 몸무게 : 88
# 키 : 150
# BMI : 39.111111111111114
# 결과 : 과체중
#
# 이름 : 카바
# 몸무게 : 55
# 키 : 154
# BMI : 23.19109461966605
# 결과 : 정상 체중
#
# 이름 : 자라
# 몸무게 : 87
# 키 : 169
# BMI : 30.461118308182492
# 결과 : 과체중
#
# 이름 : 차차
# 몸무게 : 45
# 키 : 187
# BMI : 12.868540707483769
# 결과 : 저체중
#
# 이름 : 타라
# 몸무게 : 41
# 키 : 199
# BMI : 10.353273907224565
# 결과 : 저체중
#
# 이름 : 나라
# 몸무게 : 85
# 키 : 165
# BMI : 31.22130394857668
# 결과 : 과체중
#
# 이름 : 파나
# 몸무게 : 65
# 키 : 148
# BMI : 29.674945215485756
# 결과 : 과체중
#
# 이름 : 카가
# 몸무게 : 74
# 키 : 171
# BMI : 25.3069320474676
# 결과 : 과체중
#
# 이름 : 바다
# 몸무게 : 70
# 키 : 152
# BMI : 30.297783933518005
# 결과 : 과체중
#
# 이름 : 파바
# 몸무게 : 75
# 키 : 182
# BMI : 22.6421929718633
# 결과 : 정상 체중
#
# 이름 : 가카
# 몸무게 : 46
# 키 : 161
# BMI : 17.746228926353147
# 결과 : 저체중
#
# 이름 : 나라
# 몸무게 : 44
# 키 : 171
# BMI : 15.047365001196951
# 결과 : 저체중
#
# 이름 : 아차
# 몸무게 : 99
# 키 : 166
# BMI : 35.9268398896792
# 결과 : 과체중
#
# 이름 : 가자
# 몸무게 : 72
# 키 : 192
# BMI : 19.53125
# 결과 : 정상 체중
#
# 이름 : 바가
# 몸무게 : 61
# 키 : 155
# BMI : 25.390218522372525
# 결과 : 과체중
#
# 이름 : 차가
# 몸무게 : 65
# 키 : 163
# BMI : 24.46460160337235
# 결과 : 정상 체중
#
# 이름 : 차마
# 몸무게 : 82
# 키 : 143
# BMI : 40.099760379480664
# 결과 : 과체중
#
# 이름 : 다아
# 몸무게 : 47
# 키 : 195
# BMI : 12.360289283366207
# 결과 : 저체중
#
# 이름 : 타카
# 몸무게 : 59
# 키 : 176
# BMI : 19.047004132231404
# 결과 : 정상 체중
#
# 이름 : 차파
# 몸무게 : 79
# 키 : 178
# BMI : 24.933720489837143
# 결과 : 정상 체중
#
# 이름 : 자라
# 몸무게 : 72
# 키 : 190
# BMI : 19.94459833795014
# 결과 : 정상 체중
#
# 이름 : 바아
# 몸무게 : 50
# 키 : 190
# BMI : 13.850415512465375
# 결과 : 저체중
#
# 이름 : 카라
# 몸무게 : 87
# 키 : 166
# BMI : 31.572071418202935
# 결과 : 과체중
#
# 이름 : 마바
# 몸무게 : 41
# 키 : 173
# BMI : 13.69908784122423
# 결과 : 저체중
#
# 이름 : 가카
# 몸무게 : 81
# 키 : 170
# BMI : 28.027681660899656
# 결과 : 과체중
#
# 이름 : 라라
# 몸무게 : 40
# 키 : 180
# BMI : 12.345679012345679
# 결과 : 저체중
#
# 이름 : 아타
# 몸무게 : 86
# 키 : 150
# BMI : 38.22222222222222
# 결과 : 과체중
#
# 이름 : 나하
# 몸무게 : 49
# 키 : 196
# BMI : 12.755102040816327
# 결과 : 저체중
#
# 이름 : 하하
# 몸무게 : 85
# 키 : 148
# BMI : 38.805697589481376
# 결과 : 과체중
#
# 이름 : 마자
# 몸무게 : 50
# 키 : 155
# BMI : 20.811654526534856
# 결과 : 정상 체중
#
# 이름 : 나라
# 몸무게 : 74
# 키 : 148
# BMI : 33.78378378378378
# 결과 : 과체중
#
# 이름 : 라나
# 몸무게 : 79
# 키 : 182
# BMI : 23.849776597029344
# 결과 : 정상 체중
#
# 이름 : 아자
# 몸무게 : 78
# 키 : 179
# BMI : 24.343809494085704
# 결과 : 정상 체중
#
# 이름 : 가나
# 몸무게 : 50
# 키 : 182
# BMI : 15.094795314575533
# 결과 : 저체중
#
# 이름 : 나가
# 몸무게 : 75
# 키 : 192
# BMI : 20.345052083333332
# 결과 : 정상 체중
#
# 이름 : 라아
# 몸무게 : 95
# 키 : 151
# BMI : 41.6648392614359
# 결과 : 과체중
#
# 이름 : 타아
# 몸무게 : 73
# 키 : 180
# BMI : 22.530864197530864
# 결과 : 정상 체중
#
# 이름 : 아사
# 몸무게 : 94
# 키 : 169
# BMI : 32.91201288470292
# 결과 : 과체중
#
# 이름 : 아카
# 몸무게 : 42
# 키 : 174
# BMI : 13.87237415774871
# 결과 : 저체중
#
# 이름 : 나카
# 몸무게 : 55
# 키 : 177
# BMI : 17.555619394171533
# 결과 : 저체중
#
# 이름 : 사타
# 몸무게 : 95
# 키 : 153
# BMI : 40.582681874492714
# 결과 : 과체중
#
# 이름 : 가마
# 몸무게 : 47
# 키 : 174
# BMI : 15.523847271766416
# 결과 : 저체중

# %%
# generator
# 함수를 선언합니다
def test():
    print("함수가 호출되었습니다.")
    yield "test"
    
# 함수를 호출합니다
print("A 지점 통과")
test()

print("B 지점 통과")
test()
print(test())
# Out:
# A 지점 통과
# B 지점 통과
# <generator object test at 0x7fa6c8046190>

# %%
# generator01
# 함수를 선언합니다
def test():
    print("A 지점 통과")
    yield 1
    print("B 지점 통과")
    yield 2
    print("C 지점 통과")
# 함수를 호출합니다
output = test()
# next() 함수를 호출합니다
print("D 지점 통과")
a = next(output)
print(a)
print("E 지점 통과")
b = next(output)
print(b)
print("F 지점 통과")
c = next(output)
print(c)
# 한 번 더 실행하기
next(output)
# Out:
# D 지점 통과
# A 지점 통과
# 1
# E 지점 통과
# B 지점 통과
# 2
# F 지점 통과
# C 지점 통과
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Input In [19], in <cell line: 19>()
#      17 print(b)
#      18 print("F 지점 통과")
# ---> 19 c = next(output)
#      20 print(c)
#      21 # 한 번 더 실행하기
#
# StopIteration:

# %%
# func_as_keyparam
books = [{
    "제목" : "혼자 공부하는 파이썬", 
    "가격" : 18000
}, {
    "제목" : "혼자 공부하는 머신러닝 + 딥러닝", 
    "가격" : 26000
}, {
    "제목" : "혼자 공부하는 자바스크립트", 
    "가격" : 24000
}]

def 가격추출함수(book):
    return book["가격"]

print("# 가장 저렴한 책")
print(min(books, key = 가격추출함수))
print()

print("# 가장 비싼 책")
print(max(books, key = 가격추출함수))
# Out:
# # 가장 저렴한 책
# {'제목': '혼자 공부하는 파이썬', '가격': 18000}
#
# # 가장 비싼 책
# {'제목': '혼자 공부하는 머신러닝 + 딥러닝', '가격': 26000}

# %%
# lambda03
books = [{
    "제목" : "혼자 공부하는 파이썬", 
    "가격" : 18000
}, {
    "제목" : "혼자 공부하는 머신러닝 + 딥러닝", 
    "가격" : 26000
}, {
    "제목" : "혼자 공부하는 자바스크립트", 
    "가격" : 24000
}]


print("# 가장 저렴한 책")
print(min(books, key = lambda book : book["가격"]))
print()

print("# 가장 비싼 책")
print(max(books, key = lambda book : book["가격"]))
# Out:
# # 가장 저렴한 책
# {'제목': '혼자 공부하는 파이썬', '가격': 18000}
#
# # 가장 비싼 책
# {'제목': '혼자 공부하는 머신러닝 + 딥러닝', '가격': 26000}

# %%
# lambda04
books = [{
    "제목" : "혼자 공부하는 파이썬", 
    "가격" : 18000
}, {
    "제목" : "혼자 공부하는 머신러닝 + 딥러닝", 
    "가격" : 26000
}, {
    "제목" : "혼자 공부하는 자바스크립트", 
    "가격" : 24000
}]

print("# 가격 오름차순 정렬")
books.sort(key = lambda book : book["가격"])
for book in books:
    print(book)
# Out:
# # 가격 오름차순 정렬
# {'제목': '혼자 공부하는 파이썬', '가격': 18000}
# {'제목': '혼자 공부하는 자바스크립트', '가격': 24000}
# {'제목': '혼자 공부하는 머신러닝 + 딥러닝', '가격': 26000}

# %%
# 도전문제 1
# ht = 하노이탑, mc = 이동해야하는원판, sp = 시작기둥, tp = 보조기둥, ap = 보조기둥, count = 횟수, htcount = 하노이탑이동횟수
def ht(mc, sp, tp, ap):
    if mc == 1:
        print(sp, "->", tp)
    else:
        ht(mc - 1, sp, ap, tp)
        print(sp, "->", tp)
        ht(mc - 1, ap, tp, sp)
        
n = int(input("원판의 개수를 입력해주세요 : "))
ht(n, "A탑", "B탑", "C탑")
# Out:
# 원판의 개수를 입력해주세요 : 4
# A탑 -> C탑
# A탑 -> B탑
# C탑 -> B탑
# A탑 -> C탑
# B탑 -> A탑
# B탑 -> C탑
# A탑 -> C탑
# A탑 -> B탑
# C탑 -> B탑
# C탑 -> A탑
# B탑 -> A탑
# C탑 -> B탑
# A탑 -> C탑
# A탑 -> B탑
# C탑 -> B탑

# %%
# 도전문제 2
count = 0
def ht(mc, sp, tp, ap):
    global count
    if mc == 1:
        # print(sp, "->", tp)
        count += 1
    else:
        ht(mc - 1, sp, ap, tp)
        #print(sp, "->", tp)
        count += 1
        ht(mc - 1, ap, tp, sp)
        
n = int(input("원판의 개수를 입력해주세요 : "))
ht(n, "A탑", "B탑", "C탑")
print(f"이동 횟수는 {count}회입니다.")
# Out:
# 원판의 개수를 입력해주세요 : 26
# 이동 횟수는 67108863회입니다.

# %%
# 도전문제 2 간략화
def htcount(n):
    return (2 ** n) - 1

n = int(input("원판의 개수를 입력해주세요 : "))
print(f"이동 횟수는 {htcount(n)}회입니다.")
# Out:
# 원판의 개수를 입력해주세요 : 26
# 이동 횟수는 67108863회입니다.
