# %%
pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /Users/yeohye99/opt/anaconda3/lib/python3.9/site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/yeohye99/opt/anaconda3/lib/python3.9/site-packages (from beautifulsoup4) (2.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# beautiful_weather
# 모듈을 읽어들입니다
from urllib import request
from bs4 import BeautifulSoup

# urlopen() 함수로 기상청의 전국 날씨를 읽습니다.
target = request.urlopen("http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=108")

# BeautifulSoup을 사용해 웹 페이지를 분석합니다
soup = BeautifulSoup(target, "html.parser")

# location 태그를 찾습니다
for location in soup.select("location"):
    # 내부의 city, wf, tmn, tmx 태그를 찾아 출력합니다
    print("도시 : ", location.select_one("city").string)
    print("날씨 : ", location.select_one("wf").string)
    print("최저기온 : ", location.select_one("tmn").string)
    print("최고기온 : ", location.select_one("tmx").string)
    print()
# Out:
# /Users/yeohye99/opt/anaconda3/lib/python3.9/site-packages/bs4/builder/__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(
# 도시 :  서울
# 날씨 :  흐림
# 최저기온 :  -3
# 최고기온 :  2
#
# 도시 :  인천
# 날씨 :  흐림
# 최저기온 :  -2
# 최고기온 :  2
#
# 도시 :  수원
# 날씨 :  흐림
# 최저기온 :  -4
# 최고기온 :  3
#
# 도시 :  파주
# 날씨 :  흐림
# 최저기온 :  -5
# 최고기온 :  1
#
# 도시 :  이천
# 날씨 :  흐림
# 최저기온 :  -7
# 최고기온 :  1
#
# 도시 :  평택
# 날씨 :  흐림
# 최저기온 :  -4
# 최고기온 :  3
#
# 도시 :  춘천
# 날씨 :  흐리고 눈
# 최저기온 :  -8
# 최고기온 :  1
#
# 도시 :  원주
# 날씨 :  흐리고 눈
# 최저기온 :  -6
# 최고기온 :  2
#
# 도시 :  강릉
# 날씨 :  구름많음
# 최저기온 :  -1
# 최고기온 :  6
#
# 도시 :  대전
# 날씨 :  구름많음
# 최저기온 :  -5
# 최고기온 :  5
#
# 도시 :  세종
# 날씨 :  구름많음
# 최저기온 :  -5
# 최고기온 :  4
#
# 도시 :  홍성
# 날씨 :  구름많음
# 최저기온 :  -5
# 최고기온 :  4
#
# 도시 :  청주
# 날씨 :  구름많음
# 최저기온 :  -4
# 최고기온 :  4
#
# 도시 :  충주
# 날씨 :  구름많음
# 최저기온 :  -8
# 최고기온 :  3
#
# 도시 :  영동
# 날씨 :  구름많음
# 최저기온 :  -9
# 최고기온 :  5
#
# 도시 :  광주
# 날씨 :  구름많음
# 최저기온 :  -3
# 최고기온 :  8
#
# 도시 :  목포
# 날씨 :  구름많음
# 최저기온 :  -2
# 최고기온 :  8
#
# 도시 :  여수
# 날씨 :  구름많음
# 최저기온 :  -1
# 최고기온 :  7
#
# 도시 :  순천
# 날씨 :  구름많음
# 최저기온 :  -4
# 최고기온 :  8
#
# 도시 :  광양
# 날씨 :  구름많음
# 최저기온 :  -3
# 최고기온 :  8
#
# 도시 :  나주
# 날씨 :  구름많음
# 최저기온 :  -5
# 최고기온 :  8
#
# 도시 :  전주
# 날씨 :  구름많음
# 최저기온 :  -3
# 최고기온 :  7
#
# 도시 :  군산
# 날씨 :  구름많음
# 최저기온 :  -4
# 최고기온 :  6
#
# 도시 :  정읍
# 날씨 :  구름많음
# 최저기온 :  -4
# 최고기온 :  7
#
# 도시 :  남원
# 날씨 :  구름많음
# 최저기온 :  -5
# 최고기온 :  7
#
# 도시 :  고창
# 날씨 :  구름많음
# 최저기온 :  -4
# 최고기온 :  7
#
# 도시 :  무주
# 날씨 :  구름많음
# 최저기온 :  -7
# 최고기온 :  5
#
# 도시 :  부산
# 날씨 :  맑음
# 최저기온 :  -1
# 최고기온 :  9
#
# 도시 :  울산
# 날씨 :  맑음
# 최저기온 :  -4
# 최고기온 :  8
#
# 도시 :  창원
# 날씨 :  맑음
# 최저기온 :  -4
# 최고기온 :  7
#
# 도시 :  진주
# 날씨 :  맑음
# 최저기온 :  -7
# 최고기온 :  7
#
# 도시 :  거창
# 날씨 :  맑음
# 최저기온 :  -8
# 최고기온 :  5
#
# 도시 :  통영
# 날씨 :  맑음
# 최저기온 :  -2
# 최고기온 :  8
#
# 도시 :  대구
# 날씨 :  맑음
# 최저기온 :  -4
# 최고기온 :  6
#
# 도시 :  안동
# 날씨 :  맑음
# 최저기온 :  -8
# 최고기온 :  4
#
# 도시 :  포항
# 날씨 :  맑음
# 최저기온 :  -2
# 최고기온 :  8
#
# 도시 :  경주
# 날씨 :  맑음
# 최저기온 :  -5
# 최고기온 :  8
#
# 도시 :  울진
# 날씨 :  맑음
# 최저기온 :  -2
# 최고기온 :  8
#
# 도시 :  울릉도
# 날씨 :  맑음
# 최저기온 :  2
# 최고기온 :  6
#
# 도시 :  제주
# 날씨 :  구름많음
# 최저기온 :  4
# 최고기온 :  13
#
# 도시 :  서귀포
# 날씨 :  구름많음
# 최저기온 :  5
# 최고기온 :  13

# %%
pip install flask
# Out:
# Requirement already satisfied: flask in /Users/yeohye99/opt/anaconda3/lib/python3.9/site-packages (1.1.2)
# Requirement already satisfied: Jinja2>=2.10.1 in /Users/yeohye99/opt/anaconda3/lib/python3.9/site-packages (from flask) (2.11.3)
# Requirement already satisfied: Werkzeug>=0.15 in /Users/yeohye99/opt/anaconda3/lib/python3.9/site-packages (from flask) (2.0.3)
# Requirement already satisfied: itsdangerous>=0.24 in /Users/yeohye99/opt/anaconda3/lib/python3.9/site-packages (from flask) (2.0.1)
# Requirement already satisfied: click>=5.1 in /Users/yeohye99/opt/anaconda3/lib/python3.9/site-packages (from flask) (8.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/yeohye99/opt/anaconda3/lib/python3.9/site-packages (from Jinja2>=2.10.1->flask) (2.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# flask_basic
from flask import Flask
app = Flask(__name__)

@app.route("/")
def hello():
    return "<h1>Hello World!</h1>"

# 실행 시 터미널에
# export FLASK_APP=파일이름.py
# flask run
# 을 입력

# %%
# beautiful_flask
# 모듈을 읽어들입니다
from flask import Flask
from urllib import request
from bs4 import BeautifulSoup

# 웹 서버를 생성합니다
app = Flask(__name__)
@app.route("/")

def hello():
    # urlopen() 함수로 기상청의 전국 날씨를 읽습니다
    target = request.urlopen("http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=108")
    
    # BeautifulSoup를 사용해 웹 페이지를 분석합니다
    soup = BeautifulSoup(target, "html.parser")
    
    # location 태그를 찾습니다
    output = ""
    for location in soup.select("location"):
        # 내부의 city, wf, tmn, tmx 태그를 찾아 출력합니다
        output += "<h3>{}</h3>".format(location.select_one("city").string)
        output += "날씨 : {}<br/>".format(location.select_one("wf").string)
        output += "최저/최고 기온 : {}/{}".format(\
                                           location.select_one("tmn").string, \
                                           location.select_one("tmx").string)
        output += "<hr/>"
    return output

# 전과 같은 방법으로 실행 후 웹 브라우저에 http://127.0.0.1:5000 접속

# %%
# func_deco
# 함수 데코레이터를 생성합니다
def test(function):
    def wrapper():
        print("인사가 시작되었습니다.")
        function()
        print("인사가 종료되었습니다.")
    return wrapper
    
# 데코레이터를 붙여 함수를 만듭니다
@test
def hello():
    print("hello")
    
# 함수를 호출합니다
hello()
# Out:
# 인사가 시작되었습니다.
# hello
# 인사가 종료되었습니다.

# %%
# 모듈을 가져옵니다
from functools import wraps

# 함수로 데코레이터를 생성합니다
def test(function):
    @wraps(function)
    def wrapper(*arg, **kwargs): # 가변 매개변수와 키워드 가변 매개변수를 사용하는 코드
        print("인사가 시작되었습니다.")
        function(*arg, **kwargs)
        print("인사가 종료되었습니다.")
    return wrapper
